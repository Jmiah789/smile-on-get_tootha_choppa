# %%
import pandas as pd
import numpy as np
import pickle
pd.set_option('display.max_columns', None)

# %%
# %%time
smileon = pd.read_pickle("../data/smileon.pkl")
# Out:
# Wall time: 765 ms

# %%
smileon.head(2)
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
#
#    PhoneWorkerNum   CityName  CountyName StateProvince    CountryName  \
# 0          123747     Smyrna  Rutherford            TN  United States
# 1          123747  Nashville    Davidson            TN  United States
#
#    PostalCode PhoneType ThirdPartyStateProvince  \
# 0     37167.0    Mobile                     NaN
# 1     37211.0       NaN                     NaN
#
#                                            Narrative Feedback  \
# 0  spoke with client again concerning transfer to...      NaN
# 1  Called client to follow up on app. LM for call...      NaN
#
#    EnteredByWorkerNum        EnteredOn Reviewed FeedbackStatus  \
# 0              123747  9/30/2021 16:57       No        Not yet
# 1              123747  9/30/2021 16:53       No        Not yet
#
#    FeedbackFromPhoneWorkerNum FeedbackFromPhoneWorkerName ReferralsMade  \
# 0                         NaN                         NaN           NaN
# 1                         NaN                         NaN           NaN
#
#    OrgNum Demo_# of People in Household Birth Year Demo_Other Language  \
# 0   51426                           1.0       1960                 NaN
# 1   51426                           1.0       1959                 NaN
#
#   Notes (Optional) - Notes  OralCare_1351  OralCare_1354  OralCare_2140  \
# 0                      NaN            NaN            NaN            NaN
# 1                      NaN            NaN            NaN            NaN
#
#    OralCare_2150  OralCare_2160  OralCare_2161  OralCare_230  OralCare_2330  \
# 0            NaN            NaN            NaN           NaN            NaN
# 1            NaN            NaN            NaN           NaN            NaN
#
#    OralCare_2331  OralCare_2332  OralCare_2335  OralCare_2390  OralCare_2391  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
#
#    OralCare_2392 OralCare_2393  OralCare_2394  OralCare_2915  OralCare_2920  \
# 0            NaN           NaN            NaN            NaN            NaN
# 1            NaN           NaN            NaN            NaN            NaN
#
#    OralCare_2933  OralCare_2940 OralCare_2950  OralCare_2954  OralCare_2980  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_3220  OralCare_4341 OralCare_4342  OralCare_6930  OralCare_6980  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_7111 OralCare_7140  OralCare_7210  OralCare_7220  OralCare_7230  \
# 0            NaN           NaN            NaN            NaN            NaN
# 1            NaN           NaN            NaN            NaN            NaN
#
#    OralCare_7240  OralCare_7241  OralCare_7250  OralCare_7261  OralCare_7286  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
#
#    OralCare_7310  OralCare_7311 OralCare_7320  OralCare_7321  OralCare_7410  \
# 0            NaN            NaN           NaN            NaN            NaN
# 1            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_7411  OralCare_7471  OralCare_7510  OralCare_7971  OralCare_7972  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
#
#    OralCare_9110  OralCare_9951 OralCare_Lab Assist narrative  \
# 0            NaN            NaN                           NaN
# 1            NaN            NaN                           NaN
#
#   Screen_Last Screening Date VOE_Verification Date  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
#
#   Baseline_Are you limited in what you can eat?  \
# 0                                           Yes
# 1                                           Yes
#
#                     Baseline_Dental Clinic  \
# 0  Interfaith Dental Clinic - Murfreesboro
# 1     Interfaith Dental Clinic - Nashville
#
#   Baseline_Did the client commit to referral?  \
# 0                                         Yes
# 1                                         Yes
#
#   Baseline_Did you help in these other areas?  \
# 0                                         NaN
# 1                                         NaN
#
#   Baseline_Do you need help in these other areas?  \
# 0                                              No
# 1                                              No
#
#   Baseline_Have you ever felt that the appearance of your mouth and teeth affected your quality of life?  \
# 0                                                Yes
# 1                                                Yes
#
#   Baseline_How would you describe the condition of your mouth and teeth?  \
# 0                                               Poor
# 1                                               Poor
#
#   Baseline_What is the next step for client encounter?  \
# 0                                                NaN
# 1                                                NaN
#
#   Baseline_What is the next step for clients encounter? CM_Dental Clinic  \
# 0                          Referred to dental clinic                 NaN
# 1                          Referred to dental clinic                 NaN
#
#   CM_Transportation Barriers  \
# 0                        NaN
# 1                        NaN
#
#   CM_What barriers have kept you from finding a consistent dental home? (Select all that apply)  \
# 0                                       No insurance
# 1                          Dental cost; No insurance
#
#   CM_What is the outcome for the client?  \
# 0                                    NaN
# 1                                    NaN
#
#   Clinic_Action: Upload Before Picture on Finish Tab  \
# 0                                                NaN
# 1                                                NaN
#
#   Clinic_Is patient of record date if yes last seen?  \
# 0                                                NaN
# 1                                                NaN
#
#   Clinic_Was initial appointment made?  \
# 0                                  NaN
# 1                                  NaN
#
#   Clinic_Was initial transportation assistance or referral provided?  \
# 0                                                NaN
# 1                                                NaN
#
#   Demo_Gender Demo_Household Income Level  \
# 0      Female                $0 - $21 280
# 1      Female                $0 - $21 280
#
#   Demo_How did you first hear about the program?  \
# 0                                          Other
# 1                            Dental Clinic Staff
#
#   Demo_Preferred Language/Language Needed Demo_Race/Ethnicity  \
# 0                                 English    African American
# 1                                 English           Caucasian
#
#   Demo_What other assistance programs are you on?  \
# 0                                  SNAP; SSI/SSDI
# 1                                             NaN
#
#   Demo_When is the last time you visited your dentist?  \
# 0                                                NaN
# 1                                  More than 5 years
#
#   OralCare_What care was provided to the enrollee? (Select all that apply)  \
# 0                                                NaN
# 1                                                NaN
#
#   PElig_Dental Insurance? PElig_Do they pre-qualify for SMILE ON 60+?  \
# 0                      No                                         Yes
# 1                      No                                         Yes
#
#   PElig_What is the next step for clients encounter, A?  \
# 0                          Continued with Navigation
# 1                          Continued with Navigation
#
#   PElig_What is the next step for clients encounter, B?  \
# 0                                                NaN
# 1                                                NaN
#
#    Screen_# of Lower Natural Teeth  Screen_# of Upper Natural Teeth  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
#
#   Screen_Do you have removable dentures?  \
# 0                                    NaN
# 1                                    NaN
#
#   Screen_Do you usually wear your denture(s) when you eat?  \
# 0                                                NaN
# 1                                                NaN
#
#   Screen_Experienced any problems related to mouth/teeth during past 12 months?  \
# 0                                                NaN
# 1                                                NaN
#
#   Screen_How often do you brush your teeth? Screen_Need for Periodontal Care  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
#
#   Screen_Root Fragments Screen_Suspicious Soft Tissue Lesions  \
# 0                   NaN                                   NaN
# 1                   NaN                                   NaN
#
#   Screen_Treatment Urgency Screen_Untreated Decay Site_Enroller ID  \
# 0                      NaN                    NaN              NaN
# 1                      NaN                    NaN              NaN
#
#   Site_Enroller Location TPlan_Action: Upload After Picture on Finish Tab  \
# 0                    NaN                                              NaN
# 1     Referral Follow-Up                                              NaN
#
#   TPlan_Is the treatment plan completed?  \
# 0                                    NaN
# 1                                    NaN
#
#   TPlan_Was a treatment plan developed?  \
# 0                                   NaN
# 1                                   NaN
#
#   TPlan_Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 0                                                NaN
# 1                                                NaN
#
#   VOE_Transportation Arranged VOE_Verification of Eligibility
# 0                         NaN                             NaN
# 1                         NaN                             NaN

# %%
oral_care=smileon[['OralCare_1351','OralCare_1354','OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980', 'OralCare_3220','OralCare_4341','OralCare_4342','OralCare_6930','OralCare_6980','OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972','OralCare_9110','OralCare_9951']]
oral_care
# Out:
#        OralCare_1351  OralCare_1354  OralCare_2140  OralCare_2150  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#        OralCare_2160  OralCare_2161  OralCare_230  OralCare_2330  \
# 0                NaN            NaN           NaN            NaN
# 1                NaN            NaN           NaN            NaN
# 2                NaN            NaN           NaN            NaN
# 3                NaN            NaN           NaN            NaN
# 4                NaN            NaN           NaN            NaN
# ...              ...            ...           ...            ...
# 57855            NaN            NaN           NaN            NaN
# 57856            NaN            NaN           NaN            NaN
# 57857            NaN            NaN           NaN            NaN
# 57858            NaN            NaN           NaN            NaN
# 57859            NaN            NaN           NaN            NaN
#
#        OralCare_2331  OralCare_2332  OralCare_2335  OralCare_2390  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#        OralCare_2391  OralCare_2392 OralCare_2393  OralCare_2394  \
# 0                NaN            NaN           NaN            NaN
# 1                NaN            NaN           NaN            NaN
# 2                NaN            NaN           NaN            NaN
# 3                2.0            1.0             1            NaN
# 4                NaN            NaN           NaN            NaN
# ...              ...            ...           ...            ...
# 57855            NaN            NaN           NaN            NaN
# 57856            NaN            NaN           NaN            NaN
# 57857            NaN            NaN           NaN            NaN
# 57858            NaN            NaN           NaN            NaN
# 57859            NaN            NaN           NaN            NaN
#
#        OralCare_2915  OralCare_2920  OralCare_2933  OralCare_2940  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#       OralCare_2950  OralCare_2954  OralCare_2980  OralCare_3220  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 57855           NaN            NaN            NaN            NaN
# 57856           NaN            NaN            NaN            NaN
# 57857           NaN            NaN            NaN            NaN
# 57858           NaN            NaN            NaN            NaN
# 57859           NaN            NaN            NaN            NaN
#
#        OralCare_4341 OralCare_4342  OralCare_6930  OralCare_6980  \
# 0                NaN           NaN            NaN            NaN
# 1                NaN           NaN            NaN            NaN
# 2                NaN           NaN            NaN            NaN
# 3                NaN           NaN            NaN            NaN
# 4                NaN           NaN            NaN            NaN
# ...              ...           ...            ...            ...
# 57855            NaN           NaN            NaN            NaN
# 57856            NaN           NaN            NaN            NaN
# 57857            NaN           NaN            NaN            NaN
# 57858            NaN           NaN            NaN            NaN
# 57859            NaN           NaN            NaN            NaN
#
#        OralCare_7111 OralCare_7140  OralCare_7210  OralCare_7220  \
# 0                NaN           NaN            NaN            NaN
# 1                NaN           NaN            NaN            NaN
# 2                NaN           NaN            NaN            NaN
# 3                NaN           NaN            NaN            NaN
# 4                NaN           NaN            NaN            NaN
# ...              ...           ...            ...            ...
# 57855            NaN           1.0            NaN            NaN
# 57856            NaN           NaN            NaN            NaN
# 57857            NaN           NaN            NaN            NaN
# 57858            NaN           NaN            NaN            NaN
# 57859            NaN           NaN            NaN            NaN
#
#        OralCare_7230  OralCare_7240  OralCare_7241  OralCare_7250  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#        OralCare_7261  OralCare_7286  OralCare_7310  OralCare_7311  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#       OralCare_7320  OralCare_7321  OralCare_7410  OralCare_7411  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 57855           NaN            NaN            NaN            NaN
# 57856           NaN            NaN            NaN            NaN
# 57857           NaN            NaN            NaN            NaN
# 57858           NaN            NaN            NaN            NaN
# 57859           NaN            NaN            NaN            NaN
#
#        OralCare_7471  OralCare_7510  OralCare_7971  OralCare_7972  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#        OralCare_9110  OralCare_9951
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 57855            NaN            NaN
# 57856            NaN            NaN
# 57857            NaN            NaN
# 57858            NaN            NaN
# 57859            NaN            NaN
#
# [57860 rows x 50 columns]

# %%
group0= smileon['OralCare_230']
group1 =smileon[['OralCare_1351','OralCare_1354']]
group2 = smileon[['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980']]
group3 = smileon[['OralCare_3220']]
group4 = smileon[['OralCare_4341','OralCare_4342']]
group6 = smileon[['OralCare_6930','OralCare_6980']]
group7 = smileon[['OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972']]
group9 = smileon[['OralCare_9110','OralCare_9951']]

# %% [markdown]
# oral_care = np.array(oral_care).astype('float32')

# %%
tp = smileon[['TPlan_Is the treatment plan completed?','TPlan_Was a treatment plan developed?']]

# %%
group0
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 57855   NaN
# 57856   NaN
# 57857   NaN
# 57858   NaN
# 57859   NaN
# Name: OralCare_230, Length: 57860, dtype: float64

# %%
#pivot_oc = pd.pivot_table (data=group1, index=['OralCare_1351','OralCare_1354'])
#pivot_oc

df1 = group2.set_index(["OralCare_2140","OralCare_2150"])['OralCare_2160'].unstack().reset_index()
df1.columns=df1.columns.tolist()
print (df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0bf0a59001d6> in <module>
#       2 #pivot_oc
#       3
# ----> 4 df1 = group2.set_index(["OralCare_2140","OralCare_2150"])['OralCare_2160'].unstack().reset_index()
#       5 df1.columns=df1.columns.tolist()
#       6 print (df1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3827         from pandas.core.reshape.reshape import unstack
#    3828
# -> 3829         return unstack(self, level, fill_value)
#    3830
#    3831     # ----------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     428         if is_extension_array_dtype(obj.dtype):
#     429             return _unstack_extension_series(obj, level, fill_value)
# --> 430         unstacker = _Unstacker(
#     431             obj.index, level=level, constructor=obj._constructor_expanddim
#     432         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     116             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     117
# --> 118         self._make_selectors()
#     119
#     120     @cache_readonly
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     165
#     166         if mask.sum() < len(self.index):
# --> 167             raise ValueError("Index contains duplicate entries, cannot reshape")
#     168
#     169         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
group1.apply(pd.Series.value_counts)
# Out:
#       OralCare_1351  OralCare_1354
# 1.0             7.0            315
# 2.0             2.0            182
# 3.0             NaN            117
# 4.0             1.0             77
# 5.0             NaN             60
# 6.0             1.0             37
# 7.0             NaN             31
# 8.0             1.0             17
# 9.0             NaN             17
# 10.0            NaN              8
# 11.0            NaN              6
# 12.0            NaN              1
# 13.0            NaN              7
# 14.0            NaN              5
# 15.0            NaN              3
# 16.0            NaN              3
# 17.0            NaN              1
# 18.0            NaN              2
# 19.0            NaN              1
# 20.0            NaN              1
# 22.0            NaN              1

# %%
filt_tpd = smileon['TPlan_Was a treatment plan developed?']=='Yes'
smileon.loc[filt_tpd]['TPlan_Is the treatment plan completed?'].str.contains('Yes').sum()

#'TPlan_Is the treatment plan completed?','TPlan_Was a treatment plan developed?'
# Out:
# 6649

# %%
group1['CallerNum'].count().reset_index() #CallerNum represents a Unique ID number for each patient
# Out:
#     OralCare_1351  OralCare_1354  CallerNum
# 0             1.0            NaN          7
# 1             2.0            NaN          2
# 2             4.0            NaN          1
# 3             6.0            NaN          1
# 4             8.0            NaN          1
# 5             NaN            1.0        315
# 6             NaN            2.0        182
# 7             NaN            3.0        117
# 8             NaN            4.0         77
# 9             NaN            5.0         60
# 10            NaN            6.0         37
# 11            NaN            7.0         31
# 12            NaN            8.0         17
# 13            NaN            9.0         17
# 14            NaN           10.0          8
# 15            NaN           11.0          6
# 16            NaN           12.0          1
# 17            NaN           13.0          7
# 18            NaN           14.0          5
# 19            NaN           15.0          3
# 20            NaN           16.0          3
# 21            NaN           17.0          1
# 22            NaN           18.0          2
# 23            NaN           19.0          1
# 24            NaN           20.0          1
# 25            NaN           22.0          1
# 26            NaN            NaN      56956

# %%
smileon['OralCare_1351'].unique()
# Out:
# array([nan,  2.,  1.,  6.,  4.,  8.])

# %% [markdown]
# 0 = ['OralCare_0230']
# 1 = ['OralCare_1351','OralCare_1354']
# 2 = ['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980']
# 3 = c
# 4 = ['OralCare_4341','OralCare_4342']
# 6 = ['OralCare_6930','OralCare_6980']
# 7 = c
# 9 = ['OralCare_9110','OralCare_9951']
#
# if 1:
#     print ('Cavity Sealants')
#     if 2:
#         print ('Restorative')
#         if 3:
#             print ('Kids Dental')
#             if 4:
#                 print ('Non-Surgical')
#                     if 6:
#                         print ('Denture Repair')
#                         if 7:
#                             print ('Oral Surgery')
#                             if 9:
#                                 print
#                             else:
#                                   print ('xray')

# %% [markdown]
# **Using CallerNum to count the patients with OralCare 1300/Cavity Sealant treatments

# %%
smileon.groupby(['OralCare_1351','OralCare_1354'],dropna=False)['CallerNum'].agg(['count'])
# Out:
#                              count
# OralCare_1351 OralCare_1354
# 1.0           NaN                7
# 2.0           NaN                2
# 4.0           NaN                1
# 6.0           NaN                1
# 8.0           NaN                1
# NaN           1.0              315
#               2.0              182
#               3.0              117
#               4.0               77
#               5.0               60
#               6.0               37
#               7.0               31
#               8.0               17
#               9.0               17
#               10.0               8
#               11.0               6
#               12.0               1
#               13.0               7
#               14.0               5
#               15.0               3
#               16.0               3
#               17.0               1
#               18.0               2
#               19.0               1
#               20.0               1
#               22.0               1
#               NaN            56956

# %% [markdown]
# ** Grouping results base on question 'Was a treatment plan developed' and honing in on 'Yes'responses

# %%
grouped_tpd = smileon.groupby('TPlan_Was a treatment plan developed?')
grouped_tpd

# %%
grouped_tpdy = grouped_tpd.get_group('Yes')
grouped_tpdy.head(2)
# Out:
#    CallReportNum          ReportVersion LinkedToCallReportNum  \
# 2       93115081  SMILE ON 60+ Clinical                   NaN
# 3       93115032  SMILE ON 60+ Clinical                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 2      9/30/2021 16:50    9/30/2021 16:51           1    2941341
# 3      9/30/2021 16:48    9/30/2021 16:49           1    3823933
#
#    PhoneWorkerNum CityName CountyName StateProvince    CountryName  \
# 2          161979  Memphis     Shelby            TN  United States
# 3          161979  Memphis     Shelby            TN  United States
#
#    PostalCode PhoneType ThirdPartyStateProvince Narrative Feedback  \
# 2     38104.0       NaN                     NaN       NaN      NaN
# 3     38109.0       NaN                     NaN       NaN      NaN
#
#    EnteredByWorkerNum        EnteredOn Reviewed FeedbackStatus  \
# 2              161979  9/30/2021 16:51       No        Not yet
# 3              161979  9/30/2021 16:49       No        Not yet
#
#    FeedbackFromPhoneWorkerNum FeedbackFromPhoneWorkerName ReferralsMade  \
# 2                         NaN                         NaN           NaN
# 3                         NaN                         NaN           NaN
#
#    OrgNum Demo_# of People in Household Birth Year Demo_Other Language  \
# 2   51426                           1.0       1942                 NaN
# 3   51426                           1.0       1960                 NaN
#
#   Notes (Optional) - Notes  OralCare_1351  OralCare_1354  OralCare_2140  \
# 2                      NaN            NaN            NaN            NaN
# 3                      NaN            NaN            NaN            NaN
#
#    OralCare_2150  OralCare_2160  OralCare_2161  OralCare_230  OralCare_2330  \
# 2            NaN            NaN            NaN           NaN            NaN
# 3            NaN            NaN            NaN           NaN            NaN
#
#    OralCare_2331  OralCare_2332  OralCare_2335  OralCare_2390  OralCare_2391  \
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            2.0
#
#    OralCare_2392 OralCare_2393  OralCare_2394  OralCare_2915  OralCare_2920  \
# 2            NaN           NaN            NaN            NaN            NaN
# 3            1.0             1            NaN            NaN            NaN
#
#    OralCare_2933  OralCare_2940 OralCare_2950  OralCare_2954  OralCare_2980  \
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_3220  OralCare_4341 OralCare_4342  OralCare_6930  OralCare_6980  \
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_7111 OralCare_7140  OralCare_7210  OralCare_7220  OralCare_7230  \
# 2            NaN           NaN            NaN            NaN            NaN
# 3            NaN           NaN            NaN            NaN            NaN
#
#    OralCare_7240  OralCare_7241  OralCare_7250  OralCare_7261  OralCare_7286  \
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
#
#    OralCare_7310  OralCare_7311 OralCare_7320  OralCare_7321  OralCare_7410  \
# 2            NaN            NaN           NaN            NaN            NaN
# 3            NaN            NaN           NaN            NaN            NaN
#
#    OralCare_7411  OralCare_7471  OralCare_7510  OralCare_7971  OralCare_7972  \
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
#
#    OralCare_9110  OralCare_9951 OralCare_Lab Assist narrative  \
# 2            NaN            NaN                           NaN
# 3            NaN            NaN                           NaN
#
#   Screen_Last Screening Date VOE_Verification Date  \
# 2                  10/8/2019             10/8/2019
# 3                 11/10/2020            11/10/2020
#
#   Baseline_Are you limited in what you can eat?  \
# 2                                            No
# 3                                           Yes
#
#                            Baseline_Dental Clinic  \
# 2  Christ Community Health Services- Broad Avenue
# 3                                             NaN
#
#   Baseline_Did the client commit to referral?  \
# 2                                         Yes
# 3                                         Yes
#
#   Baseline_Did you help in these other areas?  \
# 2                                         NaN
# 3                                         NaN
#
#   Baseline_Do you need help in these other areas?  \
# 2                                             NaN
# 3                                             NaN
#
#   Baseline_Have you ever felt that the appearance of your mouth and teeth affected your quality of life?  \
# 2                                                 No
# 3                                                Yes
#
#   Baseline_How would you describe the condition of your mouth and teeth?  \
# 2                                               Good
# 3                                               Fair
#
#   Baseline_What is the next step for client encounter?  \
# 2                          Referred to dental clinic
# 3                                                NaN
#
#   Baseline_What is the next step for clients encounter? CM_Dental Clinic  \
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
#
#   CM_Transportation Barriers  \
# 2                        NaN
# 3                        NaN
#
#   CM_What barriers have kept you from finding a consistent dental home? (Select all that apply)  \
# 2                          Dental cost; No insurance
# 3                    Dental cost; No insurance; Fear
#
#   CM_What is the outcome for the client?  \
# 2                                    NaN
# 3                                    NaN
#
#   Clinic_Action: Upload Before Picture on Finish Tab  \
# 2                                                NaN
# 3                                                NaN
#
#   Clinic_Is patient of record date if yes last seen?  \
# 2                                                NaN
# 3                                                NaN
#
#   Clinic_Was initial appointment made?  \
# 2                                  NaN
# 3                                  NaN
#
#   Clinic_Was initial transportation assistance or referral provided?  \
# 2                                                NaN
# 3                                                NaN
#
#   Demo_Gender Demo_Household Income Level  \
# 2        Male                $0 - $21 280
# 3        Male                $0 - $21 280
#
#   Demo_How did you first hear about the program?  \
# 2                            Dental Clinic Staff
# 3                            Dental Clinic Staff
#
#   Demo_Preferred Language/Language Needed Demo_Race/Ethnicity  \
# 2                                     NaN               Asian
# 3                                     NaN    African American
#
#   Demo_What other assistance programs are you on?  \
# 2                                             NaN
# 3                                             NaN
#
#   Demo_When is the last time you visited your dentist?  \
# 2                                Less than 12 months
# 3                                  More than 5 years
#
#   OralCare_What care was provided to the enrollee? (Select all that apply)  \
# 2  274 - Bitewings - four films - 5; 1110 - Proph...
# 3  2391 - Posterior one surface resin  - 15; 2392...
#
#   PElig_Dental Insurance? PElig_Do they pre-qualify for SMILE ON 60+?  \
# 2                      No                                         Yes
# 3                      No                                         Yes
#
#   PElig_What is the next step for clients encounter, A?  \
# 2                                                NaN
# 3                                                NaN
#
#   PElig_What is the next step for clients encounter, B?  \
# 2                          Continued with Navigation
# 3                          Continued with Navigation
#
#    Screen_# of Lower Natural Teeth  Screen_# of Upper Natural Teeth  \
# 2                              NaN                              NaN
# 3                              NaN                              NaN
#
#   Screen_Do you have removable dentures?  \
# 2                                    NaN
# 3                                    NaN
#
#   Screen_Do you usually wear your denture(s) when you eat?  \
# 2                                                NaN
# 3                                                NaN
#
#   Screen_Experienced any problems related to mouth/teeth during past 12 months?  \
# 2                                                NaN
# 3                                                NaN
#
#   Screen_How often do you brush your teeth? Screen_Need for Periodontal Care  \
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
#
#   Screen_Root Fragments Screen_Suspicious Soft Tissue Lesions  \
# 2                   NaN                                   NaN
# 3                   NaN                                   NaN
#
#   Screen_Treatment Urgency Screen_Untreated Decay  \
# 2                      NaN                    NaN
# 3                      NaN                    NaN
#
#                                  Site_Enroller ID Site_Enroller Location  \
# 2  Christ Community Health Services- Broad Avenue          Provider Site
# 3  Christ Community Health Services- Broad Avenue          Provider Site
#
#   TPlan_Action: Upload After Picture on Finish Tab  \
# 2                                              NaN
# 3                                              NaN
#
#   TPlan_Is the treatment plan completed?  \
# 2                                     No
# 3                                     No
#
#   TPlan_Was a treatment plan developed?  \
# 2                                   Yes
# 3                                   Yes
#
#   TPlan_Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 2                                                 No
# 3                                                 No
#
#   VOE_Transportation Arranged VOE_Verification of Eligibility
# 2                         NaN                             NaN
# 3                         NaN                             NaN

# %%
pivot_tpdy = pd.pivot_table (data=grouped_tpdy, index=['CountyName', 'Demo_# of People in Household'])#, ['demo_Birth Year'], aggfunc=np.mean)
pivot_tpdy
# Out:
#                                           CallLength  CallReportNum  \
# CountyName Demo_# of People in Household
# Anderson   1.0                              0.500000   9.053462e+07
#            3.0                              1.500000   8.810258e+07
#            1                                1.615385   6.856785e+07
#            2                                0.857143   6.572535e+07
#            3                                0.666667   7.310060e+07
# ...                                              ...            ...
# Wilson     4.0                              1.000000   9.009644e+07
#            1                                2.867816   6.904496e+07
#            2                                3.333333   6.966383e+07
#            3                                1.611111   6.976461e+07
#            4                                4.875000   7.410169e+07
#
#                                              CallerNum  EnteredByWorkerNum  \
# CountyName Demo_# of People in Household
# Anderson   1.0                            4.250102e+06       118845.000000
#            3.0                            3.054891e+06       118845.000000
#            1                              2.783878e+06       118941.807692
#            2                              2.746469e+06       118845.000000
#            3                              3.054891e+06       119124.666667
# ...                                                ...                 ...
# Wilson     4.0                            4.143115e+06       119515.000000
#            1                              2.729570e+06       127510.706897
#            2                              2.806357e+06       126317.083333
#            3                              2.669984e+06       126442.888889
#            4                              2.890217e+06       130810.875000
#
#                                           FeedbackFromPhoneWorkerNum  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                                   NaN
#            3.0                                                   NaN
#            1                                                     NaN
#            2                                                     NaN
#            3                                                     NaN
# ...                                                              ...
# Wilson     4.0                                                   NaN
#            1                                                     NaN
#            2                                                     NaN
#            3                                                     NaN
#            4                                                     NaN
#
#                                           OralCare_1351  OralCare_1354  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN           5.00
#            2                                        NaN           1.75
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_2140  OralCare_2150  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_2160  OralCare_2161  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_230  OralCare_2330  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                     NaN            NaN
#            3.0                                     NaN            NaN
#            1                                  5.000000            1.0
#            2                                       NaN            1.0
#            3                                       NaN            NaN
# ...                                                ...            ...
# Wilson     4.0                                     NaN            NaN
#            1                                  2.666667            1.0
#            2                                  2.000000            2.0
#            3                                       NaN            1.0
#            4                                       NaN            2.0
#
#                                           OralCare_2331  OralCare_2332  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        1.0            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        1.5            1.0
#            2                                        2.0            1.0
#            3                                        1.0            NaN
#            4                                        NaN            1.0
#
#                                           OralCare_2335  OralCare_2390  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        1.0            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        1.0            NaN
#            2                                        1.0            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_2391  OralCare_2392  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            1.0
#            2                                        NaN            NaN
#            3                                        1.0            1.0
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        1.0            1.0
#            2                                        1.0            1.0
#            3                                        NaN            1.0
#            4                                        NaN            NaN
#
#                                           OralCare_2394  OralCare_2920  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            1.0
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        1.5            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_2933  OralCare_2940  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_2954  OralCare_2980  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_3220  OralCare_4341  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            2.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_6930  OralCare_6980  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        1.0            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7111  OralCare_7210  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN          1.000
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN          1.125
#            2                                        NaN          1.000
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7220  OralCare_7230  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7240  OralCare_7241  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7250  OralCare_7261  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                   3.000000            NaN
#            2                                   2.333333            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7286  OralCare_7310  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            3.0
#            2                                        1.0            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7311  OralCare_7321  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7410  OralCare_7411  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7471  OralCare_7510  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_7971  OralCare_9110  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN            NaN
#            3.0                                      NaN            NaN
#            1                                        NaN            NaN
#            2                                        NaN            NaN
#            3                                        NaN            NaN
# ...                                                 ...            ...
# Wilson     4.0                                      NaN            NaN
#            1                                        NaN            1.0
#            2                                        NaN            NaN
#            3                                        NaN            NaN
#            4                                        NaN            NaN
#
#                                           OralCare_9951  OrgNum  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                      NaN   51426
#            3.0                                      NaN   51426
#            1                                        NaN   51426
#            2                                        NaN   51426
#            3                                        NaN   51426
# ...                                                 ...     ...
# Wilson     4.0                                      NaN   51426
#            1                                        1.0   51426
#            2                                        NaN   51426
#            3                                        NaN   51426
#            4                                        NaN   51426
#
#                                           PhoneWorkerNum    PostalCode  \
# CountyName Demo_# of People in Household
# Anderson   1.0                             118845.000000  37818.833333
#            3.0                             118845.000000  37716.000000
#            1                               118941.807692  37769.615385
#            2                               118845.000000  37710.000000
#            3                               119124.666667  37716.000000
# ...                                                  ...           ...
# Wilson     4.0                             135611.000000  37087.000000
#            1                               127788.224138  37104.018634
#            2                               126987.750000  37104.166667
#            3                               127270.000000  37101.411765
#            4                               132822.875000  37108.875000
#
#                                           Screen_# of Lower Natural Teeth  \
# CountyName Demo_# of People in Household
# Anderson   1.0                                                  12.000000
#            3.0                                                  14.000000
#            1                                                     7.833333
#            2                                                    11.000000
#            3                                                    14.000000
# ...                                                                   ...
# Wilson     4.0                                                  16.000000
#            1                                                     9.965517
#            2                                                     9.250000
#            3                                                    12.333333
#            4                                                     8.000000
#
#                                           Screen_# of Upper Natural Teeth
# CountyName Demo_# of People in Household
# Anderson   1.0                                                  15.000000
#            3.0                                                  14.000000
#            1                                                     5.000000
#            2                                                    10.000000
#            3                                                    14.000000
# ...                                                                   ...
# Wilson     4.0                                                  16.000000
#            1                                                     9.125000
#            2                                                     8.375000
#            3                                                    11.666667
#            4                                                    10.000000
#
# [493 rows x 53 columns]

# %%
grouped_tpdy['CallerNum'].value_counts()
# Out:
# 2849688    31
# 2860770    26
# 2891340    25
# 2867207    23
# 2937961    22
#            ..
# 3025506     1
# 4470934     1
# 2449047     1
# 4266612     1
# 4158973     1
# Name: CallerNum, Length: 6346, dtype: int64

# %% [markdown]
# group0= smileon['OralCare_230']
# group1 =smileon.groupby(['OralCare_1351','OralCare_1354'],dropna=False)
# group2 = smileon.groupby(['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980'])
# group3 = smileon['OralCare_3220']
# group4 = smileon.groupby(['OralCare_4341','OralCare_4342'])
# group6 = smileon.groupby(['OralCare_6930','OralCare_6980'])
# group7 = smileon.groupby(['OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972'])
# group9 = smileon.groupby(['OralCare_9110','OralCare_9951'])
