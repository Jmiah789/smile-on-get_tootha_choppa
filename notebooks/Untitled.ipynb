# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
smile = pd.read_csv('../data/Smileon.2021.10.17.csv', low_memory=False, skiprows=2)
smile.head()
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
# 2       93115081      SMILE ON 60+ Clinical                   NaN
# 3       93115032      SMILE ON 60+ Clinical                   NaN
# 4       93114968      SMILE ON 60+ Clinical                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
# 2      9/30/2021 16:50    9/30/2021 16:51           1    2941341
# 3      9/30/2021 16:48    9/30/2021 16:49           1    3823933
# 4      9/30/2021 16:46    9/30/2021 16:48           2    3348256
#
#    PhoneWorkerNum  WasRealCall  WasHangup  ...  \
# 0          123747          NaN        NaN  ...
# 1          123747          NaN        NaN  ...
# ...

# %%
smile = smile.dropna(axis=1,how='all')
smile.head()
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
# 2       93115081      SMILE ON 60+ Clinical                   NaN
# 3       93115032      SMILE ON 60+ Clinical                   NaN
# 4       93114968      SMILE ON 60+ Clinical                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
# 2      9/30/2021 16:50    9/30/2021 16:51           1    2941341
# 3      9/30/2021 16:48    9/30/2021 16:49           1    3823933
# 4      9/30/2021 16:46    9/30/2021 16:48           2    3348256
#
#    PhoneWorkerNum   CityName  CountyName  ...  \
# 0          123747     Smyrna  Rutherford  ...
# 1          123747  Nashville    Davidson  ...
# ...

# %%
smile = smile.drop(columns=['LinkedToCallReportNum', 'PhoneType', 'OrgNum'])

# %%
smile.head()
# Out:
#    CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0       93115324  SMILE ON 60+ Registration      9/30/2021 16:56
# 1       93115188  SMILE ON 60+ Registration      9/30/2021 16:53
# 2       93115081      SMILE ON 60+ Clinical      9/30/2021 16:50
# 3       93115032      SMILE ON 60+ Clinical      9/30/2021 16:48
# 4       93114968      SMILE ON 60+ Clinical      9/30/2021 16:46
#
#   CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum   CityName  \
# 0    9/30/2021 16:57           1    3638169          123747     Smyrna
# 1    9/30/2021 16:53           0    4431194          123747  Nashville
# 2    9/30/2021 16:51           1    2941341          161979    Memphis
# 3    9/30/2021 16:49           1    3823933          161979    Memphis
# 4    9/30/2021 16:48           2    3348256          161979    Memphis
#
#    CountyName StateProvince  ... SMILE ON 60+ Screening - Treatment Urgency  \
# ...

# %%
smile.dtypes
# Out:
# CallReportNum                                                                                                                                                               int64
# ReportVersion                                                                                                                                                              object
# CallDateAndTimeStart                                                                                                                                                       object
# CallDateAndTimeEnd                                                                                                                                                         object
# CallLength                                                                                                                                                                  int64
# ...

# %%
smile['CallDateAndTimeStart'] =  pd.to_datetime(smile['CallDateAndTimeStart'])

# %%
smile['month'] = smile['CallDateAndTimeStart'].dt.month

# %%
smile['SMILE ON 60+ Demographic Information - Gender'].value_counts(normalize=True) * 100
# Out:
# Female         62.531610
# Male           37.430021
# Transgender     0.036624
# Other           0.001744
# Name: SMILE ON 60+ Demographic Information - Gender, dtype: float64

# %%
smile['SMILE ON 60+ Demographic Information - Household Income Level'].value_counts(normalize=True) * 100
# Out:
# $0 - $21 280     76.672427
# $21246-$24280    13.199395
# $24281-$27315     4.181969
# $28806-$32920     3.629294
# $32921-$37035     1.161158
# $36366-$41560     0.424858
# $41561-$46755     0.370850
# $43926-$50200     0.104414
# $50201-$56475     0.099013
# $51486-$58840     0.046806
# $58841-$66195     0.039605
# $59046-$67480     0.032404
# $76121-$85635     0.014402
# $66606-$76120     0.007201
# $84761-$95355     0.007201
# $67481-$75915     0.005401
# $74166-$84760     0.003600
# Name: SMILE ON 60+ Demographic Information - Household Income Level, dtype: float64

# %%
smile['CountyName'].value_counts()
# Out:
# Davidson      12820
# Shelby        11495
# Rutherford     5410
# Sullivan       3067
# Knox           2470
#               ...
# Fulton            1
# Pulaski           1
# Desoto            1
# TN                1
# Walker            1
# Name: CountyName, Length: 105, dtype: int64

# %%
smile['CallLength'].mean()
# Out:
# 4.0963187003110955

# %%
smile['CallerNum'].value_counts()
# Out:
# -1          63
#  3212379    54
#  2441776    43
#  2758373    42
#  2431132    37
#             ..
#  3604783     1
#  2982163     1
#  3852376     1
#  2826507     1
#  2451720     1
# Name: CallerNum, Length: 10711, dtype: int64

# %%
duplicate_callernum = smile.duplicated(subset=['CallerNum'])

duplicate_callernum
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 57855     True
# 57856     True
# 57857     True
# 57858     True
# 57859     True
# Length: 57860, dtype: bool

# %%
duplicate_callernum.value_counts()
# Out:
# True     47149
# False    10711
# dtype: int64

# %%
duplicate_callernum.value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# True       81.4880746629796%
# False    18.511925337020394%
# dtype: object

# %%
smile.columns = smile.columns.str.replace('Demographic Information - ', 'di_')

# %%
smile
# Out:
#        CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0           93115324  SMILE ON 60+ Registration  2021-09-30 16:56:00
# 1           93115188  SMILE ON 60+ Registration  2021-09-30 16:53:00
# 2           93115081      SMILE ON 60+ Clinical  2021-09-30 16:50:00
# 3           93115032      SMILE ON 60+ Clinical  2021-09-30 16:48:00
# 4           93114968      SMILE ON 60+ Clinical  2021-09-30 16:46:00
# ...              ...                        ...                  ...
# 57855       55627514      SMILE ON 60+ Clinical  2018-08-01 08:00:00
# 57856       67251452      SMILE ON 60+ Clinical  2018-05-31 08:27:00
# 57857       53192452  SMILE ON 60+ Registration  2018-05-23 14:11:00
# 57858       67915561  SMILE ON 60+ Registration  2018-05-15 09:06:00
# 57859       67251405      SMILE ON 60+ Clinical  2018-05-10 08:25:00
#
#       CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum   CityName  \
# ...

# %%
smile['SMILE ON 60+ Site Information - Enroller ID'].value_counts()
# Out:
# Interfaith Dental Clinic - Nashville                                                    7995
# Interfaith Dental Clinic - Murfreesboro                                                 5100
# Church Health Center - Memphis                                                          5074
# Matthew Walker Comprehensive Health Center Inc. - Nashville                             3281
# Interfaith Health Clinic of Knoxville - Knoxville                                       2738
# Karis Dental Clinic - Cleveland                                                         2301
# Friends in Need Health Center - Kingsport                                               2089
# Healing Hands Health Center - Bristol                                                   1933
# Christ Community Health Services- Hickory Hill                                          1575
# Keystone Dental Care Inc. - Johnson City                                                1512
# ...

# %%
master['unweighted_impact_score'] = master[['ReferralsMade','scrn_Last Screening Date',  ]].notnull().sum(axis = 1)
