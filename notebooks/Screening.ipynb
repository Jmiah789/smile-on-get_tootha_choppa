# %%
import pandas as pd
import pickle

# %%
# %%time
smileon = pd.read_pickle("../data/smileon.pkl")
pd.set_option('display.max_columns', None)
# Out:
# Wall time: 336 ms

# %%
smileon.head()
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
# 2       93115081      SMILE ON 60+ Clinical                   NaN
# 3       93115032      SMILE ON 60+ Clinical                   NaN
# 4       93114968      SMILE ON 60+ Clinical                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
# 2      9/30/2021 16:50    9/30/2021 16:51           1    2941341
# 3      9/30/2021 16:48    9/30/2021 16:49           1    3823933
# 4      9/30/2021 16:46    9/30/2021 16:48           2    3348256
#
#    PhoneWorkerNum   CityName  CountyName StateProvince    CountryName  \
# 0          123747     Smyrna  Rutherford            TN  United States
# ...

# %%
df_screening = smileon[['Screen_# of Lower Natural Teeth', 'Screen_# of Upper Natural Teeth', 'Screen_Do you have removable dentures?', 'Screen_Do you usually wear your denture(s) when you eat?', 'Screen_Experienced any problems related to mouth/teeth during past 12 months?', 'Screen_How often do you brush your teeth?','Screen_Need for Periodontal Care', 'Screen_Root Fragments', 'Screen_Suspicious Soft Tissue Lesions', 'Screen_Treatment Urgency', 'Screen_Untreated Decay'  ]]

# %%
df_screening
# Out:
#        Screen_# of Lower Natural Teeth  Screen_# of Upper Natural Teeth  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 57855                              NaN                              NaN
# 57856                              NaN                              NaN
# 57857                              NaN                              NaN
# 57858                              NaN                              NaN
# 57859                              NaN                              NaN
#
#       Screen_Do you have removable dentures?  \
# 0                                        NaN
# ...

# %%
df_screening.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57860 entries, 0 to 57859
# Data columns (total 11 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Screen_# of Lower Natural Teeth                                                6238 non-null   float64
#  1   Screen_# of Upper Natural Teeth                                                5352 non-null   float64
#  2   Screen_Do you have removable dentures?                                         7333 non-null   object
#  3   Screen_Do you usually wear your denture(s) when you eat?                       6314 non-null   object
#  4   Screen_Experienced any problems related to mouth/teeth during past 12 months?  5378 non-null   object
#  5   Screen_How often do you brush your teeth?                                      6318 non-null   object
# ...

# %%
df_screening.describe()
# Out:
#        Screen_# of Lower Natural Teeth  Screen_# of Upper Natural Teeth
# count                      6238.000000                      5352.000000
# mean                         10.102597                         9.840060
# std                           3.184517                         3.539749
# min                           1.000000                         1.000000
# 25%                           8.000000                         7.000000
# 50%                          10.000000                        10.000000
# 75%                          13.000000                        13.000000
# max                          16.000000                        16.000000

# %%
df_screening['Screen_Do you have removable dentures?'].value_counts()
# Out:
# No                  4996
# Upper               1117
# Upper; Lower        1014
# Lower                198
# No; Upper              7
# No; Upper; Lower       1
# Name: Screen_Do you have removable dentures?, dtype: int64

# %%
df_screening['Screen_Do you usually wear your denture(s) when you eat?'].value_counts()
# Out:
# No              4451
# Upper            915
# Upper; Lower     737
# Lower            208
# Upper; No          3
# Name: Screen_Do you usually wear your denture(s) when you eat?, dtype: int64

# %%
df_screening['Screen_Experienced any problems related to mouth/teeth during past 12 months?'].nunique()
# Out:
# 126

# %%
df_screening['Screen_How often do you brush your teeth?'].value_counts()
# Out:
# twice daily          3108
# Once daily           2410
# None                  408
# three times daily     350
# four times daily       42
# Name: Screen_How often do you brush your teeth?, dtype: int64

# %%
df_screening['Screen_Need for Periodontal Care'].value_counts()
# Out:
# No            3065
# Yes           2846
# Edentulous     197
# Name: Screen_Need for Periodontal Care, dtype: int64

# %%
df_screening['Screen_Root Fragments'].value_counts()
# Out:
# No     4692
# Yes    1728
# Name: Screen_Root Fragments, dtype: int64

# %%
#HOW OFTEN ARE THOSE IN NEED OF ROOT FRAGEMENTS BRUSH THEIR TEETH, WHAT IS THE LOCATION OF THEIR DENTURES, 
#ARE THEY REMOVABLE, WHAT IS THE LEVEL OF URGENCY FOR THEIR CARE

# %%
df_screening['Screen_Suspicious Soft Tissue Lesions'].value_counts()
# Out:
# No     5708
# Yes     311
# Name: Screen_Suspicious Soft Tissue Lesions, dtype: int64

# %%
df_screening['Screen_Treatment Urgency'].value_counts()
# Out:
# Early care-within next several weeks                4713
# No obvious problem                                  1309
# Urgent Care - within next week-pain or infection     509
# Name: Screen_Treatment Urgency, dtype: int64

# %%
df_screening['Screen_Untreated Decay'].value_counts()
# Out:
# Yes           4328
# No            1981
# Edentulous     320
# Name: Screen_Untreated Decay, dtype: int64

# %%
test=df_screening.groupby(['Screen_Root Fragments', 'Screen_Treatment Urgency', 'Screen_Do you have removable dentures?'])['Screen_How often do you brush your teeth?']

# %%
print(test)
