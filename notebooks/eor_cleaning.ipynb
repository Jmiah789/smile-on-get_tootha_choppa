# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the csv file - got a dtype error, used low_memory = False since this notebook is just for cleaning
# and a different csv will be used
smile_on = pd.read_csv('../data/Smileon.2021.10.17.csv', header=None, low_memory = False)

# %%
smile_on.head()
# Out:
#                                                  0    \
# 0  FamilyandChildrensService - CallReports export...
# 1
# 2                                      CallReportNum
# 3                                           93115324
# 4                                           93115188
#
#                          1                      2                     3    \
# 0                        NaN                    NaN                   NaN
# 1                        NaN                    NaN                   NaN
# 2              ReportVersion  LinkedToCallReportNum  CallDateAndTimeStart
# 3  SMILE ON 60+ Registration                    NaN       9/30/2021 16:56
# 4  SMILE ON 60+ Registration                    NaN       9/30/2021 16:53
#
#                   4           5          6               7            8    \
# 0                 NaN         NaN        NaN             NaN          NaN
# 1                 NaN         NaN        NaN             NaN          NaN
# 2  CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  WasRealCall
# 3     9/30/2021 16:57           1    3638169          123747          NaN
# 4     9/30/2021 16:53           0    4431194          123747          NaN
#
#          9    ...                                         174  \
# 0        NaN  ...                                         NaN
# 1        NaN  ...                                         NaN
# 2  WasHangup  ...  SMILE ON 60+ Screening - Treatment Urgency
# 3        NaN  ...                                         NaN
# 4        NaN  ...                                         NaN
#
#                                         175  \
# 0                                       NaN
# 1                                       NaN
# 2  SMILE ON 60+ Screening - Untreated Decay
# 3                                       NaN
# 4                                       NaN
#
#                                            176  \
# 0                                          NaN
# 1                                          NaN
# 2  SMILE ON 60+ Site Information - Enroller ID
# 3                                          NaN
# 4                                          NaN
#
#                                                  177  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Site Information - Enroller Location
# 3                                                NaN
# 4                                 Referral Follow-Up
#
#                                                  178  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Action: Upload A...
# 3                                                NaN
# 4                                                NaN
#
#                                                  179  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Is the treatment...
# 3                                                NaN
# 4                                                NaN
#
#                                                  180  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Was a treatment ...
# 3                                                NaN
# 4                                                NaN
#
#                                                  181  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Was the enrollee...
# 3                                                NaN
# 4                                                NaN
#
#                                                  182  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Verification of Eligibility - Tra...
# 3                                                NaN
# 4                                                NaN
#
#                                                  183
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Verification of Eligibility - Ver...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 184 columns]

# %%
smile_on.shape
# Out:
# (57863, 184)

# %%
new_header = smile_on.iloc[2] #grab the first row for the header
smile_on = smile_on[3:] #take the data less the header row
smile_on.columns = new_header #set the header row as the df header
smile_on.head()
# Out:
# 2 CallReportNum              ReportVersion LinkedToCallReportNum  \
# 3      93115324  SMILE ON 60+ Registration                   NaN
# 4      93115188  SMILE ON 60+ Registration                   NaN
# 5      93115081      SMILE ON 60+ Clinical                   NaN
# 6      93115032      SMILE ON 60+ Clinical                   NaN
# 7      93114968      SMILE ON 60+ Clinical                   NaN
#
# 2 CallDateAndTimeStart CallDateAndTimeEnd CallLength CallerNum PhoneWorkerNum  \
# 3      9/30/2021 16:56    9/30/2021 16:57          1   3638169         123747
# 4      9/30/2021 16:53    9/30/2021 16:53          0   4431194         123747
# 5      9/30/2021 16:50    9/30/2021 16:51          1   2941341         161979
# 6      9/30/2021 16:48    9/30/2021 16:49          1   3823933         161979
# 7      9/30/2021 16:46    9/30/2021 16:48          2   3348256         161979
#
# 2 WasRealCall WasHangup  ... SMILE ON 60+ Screening - Treatment Urgency  \
# 3         NaN       NaN  ...                                        NaN
# 4         NaN       NaN  ...                                        NaN
# 5         NaN       NaN  ...                                        NaN
# 6         NaN       NaN  ...                                        NaN
# 7         NaN       NaN  ...                                        NaN
#
# 2 SMILE ON 60+ Screening - Untreated Decay  \
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
#
# 2     SMILE ON 60+ Site Information - Enroller ID  \
# 3                                             NaN
# 4                                             NaN
# 5  Christ Community Health Services- Broad Avenue
# 6  Christ Community Health Services- Broad Avenue
# 7  Christ Community Health Services- Broad Avenue
#
# 2 SMILE ON 60+ Site Information - Enroller Location  \
# 3                                               NaN
# 4                                Referral Follow-Up
# 5                                     Provider Site
# 6                                     Provider Site
# 7                                     Provider Site
#
# 2 SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab  \
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# 2 SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 3                                                NaN
# 4                                                NaN
# 5                                                 No
# 6                                                 No
# 7                                                 No
#
# 2 SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 3                                                NaN
# 4                                                NaN
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
#
# 2 SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 3                                                NaN
# 4                                                NaN
# 5                                                 No
# 6                                                 No
# 7                                                 No
#
# 2 SMILE ON 60+ Verification of Eligibility - Transportation Arranged  \
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# 2 SMILE ON 60+ Verification of Eligibility - Verification of Eligibility
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# [5 rows x 184 columns]

# %%
smile_on.shape
# Out:
# (57860, 184)

# %%
smile_on.reset_index(inplace=True)

# %%
smile_on.head()
# Out:
# 2  index CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0      3      93115324  SMILE ON 60+ Registration                   NaN
# 1      4      93115188  SMILE ON 60+ Registration                   NaN
# 2      5      93115081      SMILE ON 60+ Clinical                   NaN
# 3      6      93115032      SMILE ON 60+ Clinical                   NaN
# 4      7      93114968      SMILE ON 60+ Clinical                   NaN
#
# 2 CallDateAndTimeStart CallDateAndTimeEnd CallLength CallerNum PhoneWorkerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57          1   3638169         123747
# 1      9/30/2021 16:53    9/30/2021 16:53          0   4431194         123747
# 2      9/30/2021 16:50    9/30/2021 16:51          1   2941341         161979
# 3      9/30/2021 16:48    9/30/2021 16:49          1   3823933         161979
# 4      9/30/2021 16:46    9/30/2021 16:48          2   3348256         161979
#
# 2 WasRealCall  ... SMILE ON 60+ Screening - Treatment Urgency  \
# 0         NaN  ...                                        NaN
# 1         NaN  ...                                        NaN
# 2         NaN  ...                                        NaN
# 3         NaN  ...                                        NaN
# 4         NaN  ...                                        NaN
#
# 2 SMILE ON 60+ Screening - Untreated Decay  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# 2     SMILE ON 60+ Site Information - Enroller ID  \
# 0                                             NaN
# 1                                             NaN
# 2  Christ Community Health Services- Broad Avenue
# 3  Christ Community Health Services- Broad Avenue
# 4  Christ Community Health Services- Broad Avenue
#
# 2 SMILE ON 60+ Site Information - Enroller Location  \
# 0                                               NaN
# 1                                Referral Follow-Up
# 2                                     Provider Site
# 3                                     Provider Site
# 4                                     Provider Site
#
# 2 SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# 2 SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
# 2 SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# 2 SMILE ON 60+ Verification of Eligibility - Transportation Arranged  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 SMILE ON 60+ Verification of Eligibility - Verification of Eligibility
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 185 columns]

# %%
# drop all columns that only have null values
smile_on = smile_on.dropna(axis=1,how='all')
smile_on.shape
# Out:
# (57860, 131)

# %%
print(smile_on.columns.tolist())
# Out:
# ['index', 'CallReportNum', 'ReportVersion', 'LinkedToCallReportNum', 'CallDateAndTimeStart', 'CallDateAndTimeEnd', 'CallLength', 'CallerNum', 'PhoneWorkerNum', 'CityName', 'CountyName', 'StateProvince', 'CountryName', 'PostalCode', 'PhoneType', 'ThirdPartyStateProvince', 'Narrative', 'Feedback', 'EnteredByWorkerNum', 'EnteredOn', 'Reviewed', 'FeedbackStatus', 'FeedbackFromPhoneWorkerNum', 'FeedbackFromPhoneWorkerName', 'ReferralsMade', 'OrgNum', '+ Demographic Information - # of People in Household', 'Birth Year', '+ Demographic Information - Other Language', '+ Notes (Optional) - Notes', '+ Oral Care Encounter - 1351 - Quantity', '+ Oral Care Encounter - 1354 - Quantity', '+ Oral Care Encounter - 2140 - Quantity', '+ Oral Care Encounter - 2150 - Quantity', '+ Oral Care Encounter - 2160 - Quantity', '+ Oral Care Encounter - 2161 - Quantity', '+ Oral Care Encounter - 230 - Quantity', '+ Oral Care Encounter - 2330 - Quantity', '+ Oral Care Encounter - 2331 - Quantity', '+ Oral Care Encounter - 2332 - Quantity', '+ Oral Care Encounter - 2335 - Quantity', '+ Oral Care Encounter - 2390 - Quantity', '+ Oral Care Encounter - 2391 - Quantity', '+ Oral Care Encounter - 2392 - Quantity', '+ Oral Care Encounter - 2393 - Quantity', '+ Oral Care Encounter - 2394 - Quantity', '+ Oral Care Encounter - 2915 - Quantity', '+ Oral Care Encounter - 2920 - Quantity', '+ Oral Care Encounter - 2933 - Quantity', '+ Oral Care Encounter - 2940 - Quantity', '+ Oral Care Encounter - 2950 - Quantity', '+ Oral Care Encounter - 2954 - Quantity', '+ Oral Care Encounter - 2980 - Quantity', '+ Oral Care Encounter - 3220 - Quantity', '+ Oral Care Encounter - 4341 - Quantity', '+ Oral Care Encounter - 4342 - Quantity', '+ Oral Care Encounter - 6930 - Quantity', '+ Oral Care Encounter - 6980 - Quantity', '+ Oral Care Encounter - 7111 - Quantity', '+ Oral Care Encounter - 7140 - Quantity', '+ Oral Care Encounter - 7210 - Quantity', '+ Oral Care Encounter - 7220 - Quantity', '+ Oral Care Encounter - 7230 - Quantity', '+ Oral Care Encounter - 7240 - Quantity', '+ Oral Care Encounter - 7241 - Quantity', '+ Oral Care Encounter - 7250 - Quantity', '+ Oral Care Encounter - 7261 - Quantity', '+ Oral Care Encounter - 7286 - Quantity', '+ Oral Care Encounter - 7310 - Quantity', '+ Oral Care Encounter - 7311 - Quantity', '+ Oral Care Encounter - 7320 - Quantity', '+ Oral Care Encounter - 7321 - Quantity', '+ Oral Care Encounter - 7410 - Quantity', '+ Oral Care Encounter - 7411 - Quantity', '+ Oral Care Encounter - 7471 - Quantity', '+ Oral Care Encounter - 7510 - Quantity', '+ Oral Care Encounter - 7971 - Quantity', '+ Oral Care Encounter - 7972 - Quantity', '+ Oral Care Encounter - 9110 - Quantity', '+ Oral Care Encounter - 9951 - Quantity', '+ Oral Care Encounter - Lab Assist narrative', '+ Screening - Last Screening Date', '+ Verification of Eligibility - Verification Date', '+ Base-line Oral and Conditions Questions - Are you limited in what you can eat?', '+ Base-line Oral and Conditions Questions - Dental Clinic', '+ Base-line Oral and Conditions Questions - Did the client commit to referral?', '+ Base-line Oral and Conditions Questions - Did you help in these other areas?', '+ Base-line Oral and Conditions Questions - Do you need help in these other areas?', '+ Base-line Oral and Conditions Questions - Have you ever felt that the appearance of your mouth and teeth affected your quality of life?', '+ Base-line Oral and Conditions Questions - How would you describe the condition of your mouth and teeth?', '+ Base-line Oral and Conditions Questions - What is the next step for client encounter?', '+ Base-line Oral and Conditions Questions - What is the next step for clients encounter?', '+ Case Management Information - Dental Clinic', '+ Case Management Information - Transportation Barriers', '+ Case Management Information - What barriers have kept you from finding a consistent dental home? (Select all that apply)', '+ Case Management Information - What is the outcome fo ...

# %%
# figure out how to remove plus
smile_on.columns = smile_on.columns.str.replace(r'SMILE ON 60 +', '')
# Out:
# <ipython-input-56-7a85c63bffa6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   smile_on.columns = smile_on.columns.str.replace(r'SMILE ON 60 +', '')

# %%
smile_on.columns
# Out:
# Index(['index', 'CallReportNum', 'ReportVersion', 'LinkedToCallReportNum',
#        'CallDateAndTimeStart', 'CallDateAndTimeEnd', 'CallLength', 'CallerNum',
#        'PhoneWorkerNum', 'CityName',
#        ...
#        '+ Screening - Treatment Urgency', '+ Screening - Untreated Decay',
#        '+ Site Information - Enroller ID',
#        '+ Site Information - Enroller Location',
#        '+ Treatment Plan - Action: Upload After Picture on Finish Tab',
#        '+ Treatment Plan - Is the treatment plan completed?',
#        '+ Treatment Plan - Was a treatment plan developed?',
#        '+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)',
#        '+ Verification of Eligibility - Transportation Arranged',
#        '+ Verification of Eligibility - Verification of Eligibility'],
#       dtype='object', name=2, length=131)
