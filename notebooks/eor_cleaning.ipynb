# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read in file and set it up

# %%
# import the csv file - got a dtype error, used low_memory = False since this notebook is just for cleaning
# and a different csv will be used
smile_on = pd.read_csv('../data/Smileon.2021.10.17.csv', header=None, low_memory = False)

# %%
smile_on.head()
# Out:
#                                                  0    \
# 0  FamilyandChildrensService - CallReports export...
# 1
# 2                                      CallReportNum
# 3                                           93115324
# 4                                           93115188
#
#                          1                      2                     3    \
# 0                        NaN                    NaN                   NaN
# 1                        NaN                    NaN                   NaN
# 2              ReportVersion  LinkedToCallReportNum  CallDateAndTimeStart
# 3  SMILE ON 60+ Registration                    NaN       9/30/2021 16:56
# 4  SMILE ON 60+ Registration                    NaN       9/30/2021 16:53
#
#                   4           5          6               7            8    \
# 0                 NaN         NaN        NaN             NaN          NaN
# 1                 NaN         NaN        NaN             NaN          NaN
# 2  CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  WasRealCall
# 3     9/30/2021 16:57           1    3638169          123747          NaN
# 4     9/30/2021 16:53           0    4431194          123747          NaN
#
#          9    ...                                         174  \
# 0        NaN  ...                                         NaN
# 1        NaN  ...                                         NaN
# 2  WasHangup  ...  SMILE ON 60+ Screening - Treatment Urgency
# 3        NaN  ...                                         NaN
# 4        NaN  ...                                         NaN
#
#                                         175  \
# 0                                       NaN
# 1                                       NaN
# 2  SMILE ON 60+ Screening - Untreated Decay
# 3                                       NaN
# 4                                       NaN
#
#                                            176  \
# 0                                          NaN
# 1                                          NaN
# 2  SMILE ON 60+ Site Information - Enroller ID
# 3                                          NaN
# 4                                          NaN
#
#                                                  177  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Site Information - Enroller Location
# 3                                                NaN
# 4                                 Referral Follow-Up
#
#                                                  178  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Action: Upload A...
# 3                                                NaN
# 4                                                NaN
#
#                                                  179  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Is the treatment...
# 3                                                NaN
# 4                                                NaN
#
#                                                  180  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Was a treatment ...
# 3                                                NaN
# 4                                                NaN
#
#                                                  181  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Treatment Plan - Was the enrollee...
# 3                                                NaN
# 4                                                NaN
#
#                                                  182  \
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Verification of Eligibility - Tra...
# 3                                                NaN
# 4                                                NaN
#
#                                                  183
# 0                                                NaN
# 1                                                NaN
# 2  SMILE ON 60+ Verification of Eligibility - Ver...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 184 columns]

# %%
smile_on.shape
# Out:
# (57863, 184)

# %%
#got this from stack exhange - take a row and make it the header
new_header = smile_on.iloc[2] #grab the first row for the header
smile_on = smile_on[3:] #take the data less the header row
smile_on.columns = new_header #set the header row as the df header
smile_on.head()
# Out:
# 2 CallReportNum              ReportVersion LinkedToCallReportNum  \
# 3      93115324  SMILE ON 60+ Registration                   NaN
# 4      93115188  SMILE ON 60+ Registration                   NaN
# 5      93115081      SMILE ON 60+ Clinical                   NaN
# 6      93115032      SMILE ON 60+ Clinical                   NaN
# 7      93114968      SMILE ON 60+ Clinical                   NaN
#
# 2 CallDateAndTimeStart CallDateAndTimeEnd CallLength CallerNum PhoneWorkerNum  \
# 3      9/30/2021 16:56    9/30/2021 16:57          1   3638169         123747
# 4      9/30/2021 16:53    9/30/2021 16:53          0   4431194         123747
# 5      9/30/2021 16:50    9/30/2021 16:51          1   2941341         161979
# 6      9/30/2021 16:48    9/30/2021 16:49          1   3823933         161979
# 7      9/30/2021 16:46    9/30/2021 16:48          2   3348256         161979
#
# 2 WasRealCall WasHangup  ... SMILE ON 60+ Screening - Treatment Urgency  \
# 3         NaN       NaN  ...                                        NaN
# 4         NaN       NaN  ...                                        NaN
# 5         NaN       NaN  ...                                        NaN
# 6         NaN       NaN  ...                                        NaN
# 7         NaN       NaN  ...                                        NaN
#
# 2 SMILE ON 60+ Screening - Untreated Decay  \
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
#
# 2     SMILE ON 60+ Site Information - Enroller ID  \
# 3                                             NaN
# 4                                             NaN
# 5  Christ Community Health Services- Broad Avenue
# 6  Christ Community Health Services- Broad Avenue
# 7  Christ Community Health Services- Broad Avenue
#
# 2 SMILE ON 60+ Site Information - Enroller Location  \
# 3                                               NaN
# 4                                Referral Follow-Up
# 5                                     Provider Site
# 6                                     Provider Site
# 7                                     Provider Site
#
# 2 SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab  \
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# 2 SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 3                                                NaN
# 4                                                NaN
# 5                                                 No
# 6                                                 No
# 7                                                 No
#
# 2 SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 3                                                NaN
# 4                                                NaN
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
#
# 2 SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 3                                                NaN
# 4                                                NaN
# 5                                                 No
# 6                                                 No
# 7                                                 No
#
# 2 SMILE ON 60+ Verification of Eligibility - Transportation Arranged  \
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# 2 SMILE ON 60+ Verification of Eligibility - Verification of Eligibility
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# [5 rows x 184 columns]

# %%
smile_on.shape
# Out:
# (57860, 184)

# %%
smile_on.reset_index(inplace=True, drop=True)

# %%
smile_on.head()
# Out:
# 2 CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0      93115324  SMILE ON 60+ Registration                   NaN
# 1      93115188  SMILE ON 60+ Registration                   NaN
# 2      93115081      SMILE ON 60+ Clinical                   NaN
# 3      93115032      SMILE ON 60+ Clinical                   NaN
# 4      93114968      SMILE ON 60+ Clinical                   NaN
#
# 2 CallDateAndTimeStart CallDateAndTimeEnd CallLength CallerNum PhoneWorkerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57          1   3638169         123747
# 1      9/30/2021 16:53    9/30/2021 16:53          0   4431194         123747
# 2      9/30/2021 16:50    9/30/2021 16:51          1   2941341         161979
# 3      9/30/2021 16:48    9/30/2021 16:49          1   3823933         161979
# 4      9/30/2021 16:46    9/30/2021 16:48          2   3348256         161979
#
# 2 WasRealCall WasHangup  ... SMILE ON 60+ Screening - Treatment Urgency  \
# 0         NaN       NaN  ...                                        NaN
# 1         NaN       NaN  ...                                        NaN
# 2         NaN       NaN  ...                                        NaN
# 3         NaN       NaN  ...                                        NaN
# 4         NaN       NaN  ...                                        NaN
#
# 2 SMILE ON 60+ Screening - Untreated Decay  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# 2     SMILE ON 60+ Site Information - Enroller ID  \
# 0                                             NaN
# 1                                             NaN
# 2  Christ Community Health Services- Broad Avenue
# 3  Christ Community Health Services- Broad Avenue
# 4  Christ Community Health Services- Broad Avenue
#
# 2 SMILE ON 60+ Site Information - Enroller Location  \
# 0                                               NaN
# 1                                Referral Follow-Up
# 2                                     Provider Site
# 3                                     Provider Site
# 4                                     Provider Site
#
# 2 SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# 2 SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
# 2 SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# 2 SMILE ON 60+ Verification of Eligibility - Transportation Arranged  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 SMILE ON 60+ Verification of Eligibility - Verification of Eligibility
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 184 columns]

# %% [markdown]
# # Explore to begin cleaning

# %%
#explore to see if columns need to be dropped
drop = smile_on['ThirdPartyStateProvince'].unique()
drop
# Out:
# array([nan, 'TN'], dtype=object)

# %%
#explore to see if columns need to be dropped
drop = smile_on['FeedbackStatus'].unique()
drop
# Out:
# array(['Not yet', 'Seen', 'Not needed', 'To be read'], dtype=object)

# %%
#explore to see if columns need to be dropped
drop = smile_on['FeedbackFromPhoneWorkerNum'].unique()
drop
# Out:
# array([nan, '117268', '82339', '116749', '118292', '-1', '82341',
#        '117266', '60132'], dtype=object)

# %%
#explore to see if columns need to be dropped
drop = smile_on['FeedbackStatus'].unique()
drop
# Out:
# array(['Not yet', 'Seen', 'Not needed', 'To be read'], dtype=object)

# %%
#explore to see if columns need to be dropped
drop = smile_on['SMILE ON 60+ Case Management Information - What barriers have kept you from finding a consistent dental home? (Select all that apply)'].unique()
drop
# Out:
# array(['No insurance', 'Dental cost; No insurance',
#        'Dental cost; No insurance; Fear',
#        'Transportation; Dental cost; No insurance', 'Dental cost', nan,
#        'Dental cost; No insurance; Personal isolation',
#        'Dental cost; No insurance; Physical mobility and health',
#        'No insurance; Physical mobility and health', 'No insurance; Fear',
#        'Transportation; Dental cost; No insurance; Personal isolation; Fear; Physical mobility and health',
#        'Transportation; Dental cost',
#        'Transportation; Dental cost; No insurance; Physical mobility and health',
#        'Fear', 'Dental cost; Fear',
#        'No insurance; Fear; Physical mobility and health',
#        'Transportation; Dental cost; No insurance; Fear',
#        'Transportation; Dental cost; Fear',
#        'Transportation; No insurance',
#        'Dental cost; No insurance; Fear; Physical mobility and health',
#        'Dental cost; Physical mobility and health',
#        'Dental cost; Fear; Physical mobility and health',
#        'Transportation; Dental cost; No insurance; Fear; Physical mobility and health',
#        'Transportation',
#        'Transportation; Dental cost; Physical mobility and health',
#        'Transportation; Dental cost; No insurance; Personal isolation',
#        'Personal isolation',
#        'Dental cost; No insurance; Personal isolation; Fear; Physical mobility and health',
#        'Physical mobility and health', 'Personal isolation; Fear',
#        'Dental cost; No insurance; Personal isolation; Fear',
#        'No insurance; Personal isolation',
#        'Transportation; Dental cost; No insurance; Personal isolation; Fear',
#        'Transportation; Dental cost; Personal isolation',
#        'Dental cost; Personal isolation; Fear',
#        'Transportation; Personal isolation',
#        'Dental cost; No insurance; Personal isolation; Physical mobility and health',
#        'Transportation; No insurance; Physical mobility and health',
#        'Dental cost; Personal isolation',
#        'Transportation; Dental cost; Personal isolation; Physical mobility and health',
#        'Transportation; Physical mobility and health',
#        'Transportation; No insurance; Fear; Physical mobility and health',
#        'Transportation; Dental cost; Fear; Physical mobility and health',
#        'Transportation; Dental cost; No insurance; Personal isolation; Physical mobility and health',
#        'Fear; Physical mobility and health',
#        'Personal isolation; Physical mobility and health',
#        'Transportation; No insurance; Fear',
#        'Dental cost; Personal isolation; Physical mobility and health',
#        'Transportation; No insurance; Personal isolation',
#        'Transportation; Fear', 'Transportation; Personal isolation; Fear',
#        'Transportation; Fear; Physical mobility and health',
#        'Transportation; Personal isolation; Physical mobility and health'],
#       dtype=object)

# %%
# drop all columns that only have null values
smile_on = smile_on.dropna(axis=1,how='all')
#drop columns with information that is not useful
smile_on = smile_on.drop('OrgNum', axis=1)
smile_on = smile_on.drop('SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab', axis=1)
smile_on = smile_on.drop('SMILE ON 60+ Clinic Information - Action: Upload Before Picture on Finish Tab', axis=1)
smile_on = smile_on.drop('CountryName', axis=1)
smile_on = smile_on.drop('PhoneType', axis=1)
smile_on = smile_on.drop('ThirdPartyStateProvince', axis=1)
smile_on = smile_on.drop('FeedbackFromPhoneWorkerNum', axis=1)
smile_on = smile_on.drop('FeedbackFromPhoneWorkerName', axis=1)
smile_on = smile_on.drop('Narrative', axis=1)
smile_on = smile_on.drop('PhoneWorkerNum', axis=1)
smile_on = smile_on.drop('SMILE ON 60+ Notes (Optional) - Notes', axis=1)
smile_on = smile_on.drop('Feedback', axis=1)
smile_on = smile_on.drop('FeedbackStatus', axis=1)
smile_on = smile_on.drop('Reviewed', axis=1)
smile_on = smile_on.drop('SMILE ON 60+ Oral Care Encounter - Lab Assist narrative', axis=1)
smile_on.shape
# Out:
# (57860, 115)

# %%
# regex to change strings in column names
# can also remove plus with ('SMILE ON 60\\+')
smile_on.columns = smile_on.columns.str.replace(r'SMILE ON 60\+ ', '')
smile_on.columns = smile_on.columns.str.replace('Oral Care Encounter - ', 'oec_')
smile_on.columns = smile_on.columns.str.replace(' - Quantity', '')
smile_on.columns = smile_on.columns.str.replace('Demographic Information - ', 'di_')
smile_on.columns = smile_on.columns.str.replace('Base-line Oral and Conditions Questions - ', 'bocq_')
smile_on.columns = smile_on.columns.str.replace('Screening - ', 'scrn_')
smile_on.columns = smile_on.columns.str.replace('Treatment Plan - ', 'tp_')
smile_on.columns = smile_on.columns.str.replace('Presumptive Eligibility - ', 'pe_')
smile_on.columns = smile_on.columns.str.replace('Case Management Information - ', 'cmi_')
smile_on.columns = smile_on.columns.str.replace('Clinic Information - ', 'ci_')
smile_on.columns = smile_on.columns.str.replace('Verification of Eligibility - ', 've_')
smile_on.columns = smile_on.columns.str.replace('Site Information - ', 'si_')
# Out:
# <ipython-input-15-1f411c6eba5a>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   smile_on.columns = smile_on.columns.str.replace(r'SMILE ON 60\+ ', '')

# %%
print(smile_on.columns.tolist())
# Out:
# ['CallReportNum', 'ReportVersion', 'LinkedToCallReportNum', 'CallDateAndTimeStart', 'CallDateAndTimeEnd', 'CallLength', 'CallerNum', 'CityName', 'CountyName', 'StateProvince', 'PostalCode', 'EnteredByWorkerNum', 'EnteredOn', 'ReferralsMade', 'di_# of People in Household', 'Birth Year', 'di_Other Language', 'oec_1351', 'oec_1354', 'oec_2140', 'oec_2150', 'oec_2160', 'oec_2161', 'oec_230', 'oec_2330', 'oec_2331', 'oec_2332', 'oec_2335', 'oec_2390', 'oec_2391', 'oec_2392', 'oec_2393', 'oec_2394', 'oec_2915', 'oec_2920', 'oec_2933', 'oec_2940', 'oec_2950', 'oec_2954', 'oec_2980', 'oec_3220', 'oec_4341', 'oec_4342', 'oec_6930', 'oec_6980', 'oec_7111', 'oec_7140', 'oec_7210', 'oec_7220', 'oec_7230', 'oec_7240', 'oec_7241', 'oec_7250', 'oec_7261', 'oec_7286', 'oec_7310', 'oec_7311', 'oec_7320', 'oec_7321', 'oec_7410', 'oec_7411', 'oec_7471', 'oec_7510', 'oec_7971', 'oec_7972', 'oec_9110', 'oec_9951', 'scrn_Last Screening Date', 've_Verification Date', 'bocq_Are you limited in what you can eat?', 'bocq_Dental Clinic', 'bocq_Did the client commit to referral?', 'bocq_Did you help in these other areas?', 'bocq_Do you need help in these other areas?', 'bocq_Have you ever felt that the appearance of your mouth and teeth affected your quality of life?', 'bocq_How would you describe the condition of your mouth and teeth?', 'bocq_What is the next step for client encounter?', 'bocq_What is the next step for clients encounter?', 'cmi_Dental Clinic', 'cmi_Transportation Barriers', 'cmi_What barriers have kept you from finding a consistent dental home? (Select all that apply)', 'cmi_What is the outcome for the client?', 'ci_Is patient of record date if yes last seen?', 'ci_Was initial appointment made?', 'ci_Was initial transportation assistance or referral provided?', 'di_Gender', 'di_Household Income Level', 'di_How did you first hear about the program?', 'di_Preferred Language/Language Needed', 'di_Race/Ethnicity', 'di_What other assistance programs are you on?', 'di_When is the last time you visited your dentist?', 'oec_What care was provided to the enrollee? (Select all that apply)', 'pe_Dental Insurance?', 'pe_Do they pre-qualify for SMILE ON 60+?', 'pe_What is the next step for clients encounter? ', 'pe_What is the next step for clients encounter?', 'scrn_# of Lower Natural Teeth', 'scrn_# of Upper Natural Teeth', 'scrn_Do you have removable dentures?', 'scrn_Do you usually wear your denture(s) when you eat?', 'scrn_Experienced any problems related to mouth/teeth during past 12 months?', 'scrn_How often do you brush your teeth?', 'scrn_Need for Periodontal Care', 'scrn_Root Fragments', 'scrn_Suspicious Soft Tissue Lesions', 'scrn_Treatment Urgency', 'scrn_Untreated Decay', 'si_Enroller ID', 'si_Enroller Location', 'tp_Is the treatment plan completed?', 'tp_Was a treatment plan developed?', 'tp_Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)', 've_Transportation Arranged', 've_Verification of Eligibility']

# %%
#change column names
smile_on = smile_on.rename(columns={
'CallReportNum': 'report_num',
'ReportVersion': 'report_version',
'LinkedToCallReportNum': 'related_reports',
'CallDateAndTimeStart': 'call_start',
'CallDateAndTimeEnd': 'call_end',
'CallLength': 'call_length',
'CallerNum': 'patient_id',
#'PhoneWorkerNum': 'worker_id',
'CityName': 'city',
'CountyName': 'county',
'StateProvince': 'state',
'PostalCode': 'zip_code',
#'Narrative': 'narrative',
#'Feedback': 'feedback',
'EnteredOn': 'date_entered',
#'Reviewed': 'reviewed',
#'FeedbackStatus': 'feedback_status',
'ReferralsMade': 'referrals_made',
'Birth Year': 'birth_year',
#'Notes (Optional) - Notes': 'notes_optional'
#'oec_Lab Assist narrative': 'oec_lab_narrative',
'scrn_Last Screening Date': 'scrn_date_of_last',
've_Verification Date': 've_verified_date',
'bocq_Are you limited in what you can eat?': 'bocq_eat_limited',
'bocq_Dental Clinic': 'bocq_dental_clinic',
'bocq_Did the client commit to referral?': 'bocq_client_commit',
'bocq_Did you help in these other areas?': 'bocq_help_other',
'bocq_Do you need help in these other areas?': 'bocq_need_help',
'bocq_Have you ever felt that the appearance of your mouth and teeth affected your quality of life?': 'bocq_appearance',
'bocq_How would you describe the condition of your mouth and teeth?': 'bocq_condition',
'tp_Is the treatment plan completed?': 'tp_completed',
'tp_Was a treatment plan developed?': 'tp_developed',
'tp_Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)': 'tp_yay',
'bocq_What is the next step for client encounter?': 'bocq_next_step1',
'bocq_What is the next step for clients encounter?': 'bocq_next_step2',
'di_Gender': 'di_gender',
'di_Household Income Level': 'di_hh_income',
'di_How did you first hear about the program?': 'di_referred_by',
'di_Preferred Language/Language Needed': 'di_language1',
'di_Other Language': 'di_other_language',
'di_Race/Ethnicity': 'di_race_eth',
'di_What other assistance programs are you on?':'di_other_programs',
'di_When is the last time you visited your dentist?': 'di_last_dentist_visit',
'oec_What care was provided to the enrollee? (Select all that apply)': 'oec_care_provided',
'scrn_# of Lower Natural Teeth': 'scrn_lower_teeth',
'scrn_# of Upper Natural Teeth': 'scrn_upper_teeth',
'scrn_Do you have removable dentures?': 'scrn_has_dentures',
'scrn_Do you usually wear your denture(s) when you eat?': 'scrn_eats_w_dentures',
'scrn_Experienced any problems related to mouth/teeth during past 12 months?': 'scrn_problems_12m',
'scrn_How often do you brush your teeth?': 'scrn_tooth_brushing',
'scrn_Need for Periodontal Care': 'scrn_periodontal',
'scrn_Root Fragments': 'scrn_root_fragments',
'scrn_Suspicious Soft Tissue Lesions': 'scrn_lesions',
'scrn_Treatment Urgency': 'scrn_urgency',
'scrn_Untreated Decay': 'scrn_decay',
'si_Enroller ID': 'si_enroller_id',
'si_Enroller Location': 'si_enroller_location',
've_Transportation Arranged': 've_transport',
've_Verification of Eligibility': 've_eligibility_verified'
})

# %%
smile_on.head()
# Out:
# 2 report_num             report_version related_reports       call_start  \
# 0   93115324  SMILE ON 60+ Registration             NaN  9/30/2021 16:56
# 1   93115188  SMILE ON 60+ Registration             NaN  9/30/2021 16:53
# 2   93115081      SMILE ON 60+ Clinical             NaN  9/30/2021 16:50
# 3   93115032      SMILE ON 60+ Clinical             NaN  9/30/2021 16:48
# 4   93114968      SMILE ON 60+ Clinical             NaN  9/30/2021 16:46
#
# 2         call_end call_length patient_id       city      county state  ...  \
# 0  9/30/2021 16:57           1    3638169     Smyrna  Rutherford    TN  ...
# 1  9/30/2021 16:53           0    4431194  Nashville    Davidson    TN  ...
# 2  9/30/2021 16:51           1    2941341    Memphis      Shelby    TN  ...
# 3  9/30/2021 16:49           1    3823933    Memphis      Shelby    TN  ...
# 4  9/30/2021 16:48           2    3348256    Memphis      Shelby    TN  ...
#
# 2 scrn_lesions scrn_urgency scrn_decay  \
# 0          NaN          NaN        NaN
# 1          NaN          NaN        NaN
# 2          NaN          NaN        NaN
# 3          NaN          NaN        NaN
# 4          NaN          NaN        NaN
#
# 2                                  si_enroller_id si_enroller_location  \
# 0                                             NaN                  NaN
# 1                                             NaN   Referral Follow-Up
# 2  Christ Community Health Services- Broad Avenue        Provider Site
# 3  Christ Community Health Services- Broad Avenue        Provider Site
# 4  Christ Community Health Services- Broad Avenue        Provider Site
#
# 2 tp_completed tp_developed tp_yay ve_transport ve_eligibility_verified
# 0          NaN          NaN    NaN          NaN                     NaN
# 1          NaN          NaN    NaN          NaN                     NaN
# 2           No          Yes     No          NaN                     NaN
# 3           No          Yes     No          NaN                     NaN
# 4           No          Yes     No          NaN                     NaN
#
# [5 rows x 115 columns]

# %%
smile_on.loc[:,['oec_care_provided', 'oec_2391', 'oec_2392']]
# Out:
# 2                                      oec_care_provided oec_2391 oec_2392
# 0                                                    NaN      NaN      NaN
# 1                                                    NaN      NaN      NaN
# 2      274 - Bitewings - four films - 5; 1110 - Proph...      NaN      NaN
# 3      2391 - Posterior one surface resin  - 15; 2392...        2        1
# 4      No Code - Denture step Mandibular: may be used...      NaN      NaN
# ...                                                  ...      ...      ...
# 57855  5222 - Partial denture - resin base - immediat...      NaN      NaN
# 57856                                                NaN      NaN      NaN
# 57857                                                NaN      NaN      NaN
# 57858                                                NaN      NaN      NaN
# 57859                                                NaN      NaN      NaN
#
# [57860 rows x 3 columns]

# %% [markdown]
# # Base-Line Oral and Condition Columns - merging two columns together

# %%
#cell to compare contents of two different columns
smile_on.loc[:,['bocq_next_step1', 'bocq_next_step2']].head(10)
#filter where they're both not null and - for each column
#next step - 1 not null
#next stop - 2 not null
# Out:
# 2            bocq_next_step1            bocq_next_step2
# 0                        NaN  Referred to dental clinic
# 1                        NaN  Referred to dental clinic
# 2  Referred to dental clinic                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN  Referred to dental clinic
# 6                        NaN  Referred to dental clinic
# 7                        NaN  Referred to dental clinic
# 8                        NaN                        NaN
# 9                        NaN                        NaN

# %%
#are any rows that are not null in bocq1 also not null in bocq2?
compare_next_step = (smile_on['bocq_next_step1'].notnull() == smile_on['bocq_next_step2'].notnull()).all()
compare_next_step
# Out:
# False

# %%
# where rows are both null
smile_on.loc[(smile_on['bocq_next_step1'].isnull()) & (smile_on['bocq_next_step2'].isnull())]
# Out:
# 2     report_num             report_version related_reports       call_start  \
# 3       93115032      SMILE ON 60+ Clinical             NaN  9/30/2021 16:48
# 4       93114968      SMILE ON 60+ Clinical             NaN  9/30/2021 16:46
# 8       93114520      SMILE ON 60+ Clinical             NaN  9/30/2021 16:35
# 9       93154018      SMILE ON 60+ Clinical             NaN  9/30/2021 16:09
# 10      93292560      SMILE ON 60+ Clinical             NaN  9/30/2021 15:35
# ...          ...                        ...             ...              ...
# 57854   55104302  SMILE ON 60+ Registration             NaN    8/1/2018 8:18
# 57855   55627514      SMILE ON 60+ Clinical             NaN    8/1/2018 8:00
# 57856   67251452      SMILE ON 60+ Clinical             NaN   5/31/2018 8:27
# 57857   53192452  SMILE ON 60+ Registration             NaN  5/23/2018 14:11
# 57859   67251405      SMILE ON 60+ Clinical             NaN   5/10/2018 8:25
#
# 2             call_end call_length patient_id         city      county state  \
# 3      9/30/2021 16:49           1    3823933      Memphis      Shelby    TN
# 4      9/30/2021 16:48           2    3348256      Memphis      Shelby    TN
# 8      9/30/2021 16:37           2    4492947   Millington      Shelby    TN
# 9      9/30/2021 16:12           3    2887352      Memphis      Shelby    TN
# 10     9/30/2021 15:36           1    2686768  White House   Robertson    TN
# ...                ...         ...        ...          ...         ...   ...
# 57854    8/1/2018 9:43          85    2384744    Nashville    Davidson    TN
# 57855    8/1/2018 8:08           8    2385621    Lascassas  Rutherford    TN
# 57856   5/31/2018 8:29           2    2631417    Kingsport    Sullivan    TN
# 57857  5/23/2018 14:11           0         -1          NaN         NaN   NaN
# 57859   5/10/2018 8:26           1    2631417    Kingsport    Sullivan    TN
#
# 2      ... scrn_lesions        scrn_urgency scrn_decay  \
# 3      ...          NaN                 NaN        NaN
# 4      ...          NaN                 NaN        NaN
# 8      ...          NaN                 NaN        NaN
# 9      ...           No  No obvious problem         No
# 10     ...          NaN                 NaN        NaN
# ...    ...          ...                 ...        ...
# 57854  ...          NaN                 NaN        NaN
# 57855  ...          NaN                 NaN        NaN
# 57856  ...          NaN                 NaN        NaN
# 57857  ...          NaN                 NaN        NaN
# 57859  ...          NaN                 NaN        NaN
#
# 2                                       si_enroller_id si_enroller_location  \
# 3       Christ Community Health Services- Broad Avenue        Provider Site
# 4       Christ Community Health Services- Broad Avenue        Provider Site
# 8            Christ Community Health Services- Raleigh        Provider Site
# 9       Christ Community Health Services- Broad Avenue        Provider Site
# 10     Neighborhood Health - Cleveland Park/ Nashville        Provider Site
# ...                                                ...                  ...
# 57854             Interfaith Dental Clinic - Nashville        Provider Site
# 57855          Interfaith Dental Clinic - Murfreesboro                  NaN
# 57856        Friends in Need Health Center - Kingsport        Provider Site
# 57857                                              NaN                  NaN
# 57859        Friends in Need Health Center - Kingsport        Provider Site
#
# 2     tp_completed tp_developed tp_yay ve_transport ve_eligibility_verified
# 3               No          Yes     No          NaN                     NaN
# 4               No          Yes     No          NaN                     NaN
# 8               No          Yes     No          NaN                     Yes
# 9              Yes          Yes    Yes          NaN                     NaN
# 10             NaN          NaN    NaN          NaN                     NaN
# ...            ...          ...    ...          ...                     ...
# 57854          NaN          NaN    NaN          NaN                     NaN
# 57855          NaN          NaN    NaN          NaN                     NaN
# 57856           No           No    Yes          NaN                     NaN
# 57857          NaN          NaN    NaN          NaN                     NaN
# 57859           No          Yes    Yes          NaN                     NaN
#
# [35525 rows x 115 columns]

# %%
#cell to explore contents of various cells
bocq1 = smile_on['bocq_next_step1'].unique()
bocq1
# Out:
# array([nan, 'Referred to dental clinic', 'Care Coordinator',
#        'Not interested in SMILE ON', 'Information Only'], dtype=object)

# %%
#cell to explore contents of various cells
bocq2 = smile_on['bocq_next_step2'].unique()
bocq2
#value count on services/wisdom tooth
# Out:
# array(['Referred to dental clinic', nan, 'Information Only',
#        'Care Coordinator', 'Not interested in SMILE ON',
#        'Services not available within SMILE ON', 'Wisdom Tooth Workshop'],
#       dtype=object)

# %%
#checking value counts on question 2
smile_on["bocq_next_step2"].value_counts()
# Out:
# Referred to dental clinic                 12353
# Care Coordinator                           1190
# Information Only                            360
# Not interested in SMILE ON                  150
# Services not available within SMILE ON       13
# Wisdom Tooth Workshop                         5
# Name: bocq_next_step2, dtype: int64

# %%
#slice based on 2 unique values
bocq3=smile_on.loc[(smile_on["bocq_next_step2"] == "Wisdom Tooth Workshop")]
bocq3
# Out:
# 2     report_num             report_version related_reports        call_start  \
# 29153   71334697  SMILE ON 60+ Registration             NaN   2/27/2020 16:53
# 43222   65222474  SMILE ON 60+ Registration             NaN    8/6/2019 15:27
# 49261   61894436  SMILE ON 60+ Registration             NaN    4/5/2019 10:10
# 54266   58308976  SMILE ON 60+ Registration             NaN  11/28/2018 14:11
# 54375   58249716  SMILE ON 60+ Registration             NaN  11/26/2018 15:58
#
# 2              call_end call_length patient_id         city      county state  \
# 29153   2/27/2020 16:55           2    3219300    La Vergne  Rutherford    TN
# 43222    8/6/2019 15:35           8    2832200  Clarksville  Montgomery    TN
# 49261    4/5/2019 10:32          22    2754521  Sevierville      Sevier    TN
# 54266  11/28/2018 14:28          17    2518608    Brentwood  Williamson    TN
# 54375  11/26/2018 16:01           3    2515680   Eagleville  Rutherford    TN
#
# 2      ... scrn_lesions scrn_urgency scrn_decay                si_enroller_id  \
# 29153  ...          NaN          NaN        NaN                           NaN
# 43222  ...          NaN          NaN        NaN  Matthew Walker - Clarksville
# 49261  ...          NaN          NaN        NaN                           NaN
# 54266  ...          NaN          NaN        NaN                           NaN
# 54375  ...          NaN          NaN        NaN                           NaN
#
# 2      si_enroller_location tp_completed tp_developed tp_yay ve_transport  \
# 29153          Tooth Wisdom          NaN          NaN    NaN          NaN
# 43222         Provider Site          NaN          NaN    NaN          NaN
# 49261  Health Assist Office          NaN          NaN    NaN          NaN
# 54266          Tooth Wisdom          NaN          NaN    NaN          NaN
# 54375          Tooth Wisdom          NaN          NaN    NaN          NaN
#
# 2     ve_eligibility_verified
# 29153                     NaN
# 43222                     NaN
# 49261                     NaN
# 54266                     NaN
# 54375                     NaN
#
# [5 rows x 115 columns]

# %%
bocq3.loc[:,['bocq_next_step1', 'bocq_next_step2']]
# Out:
# 2     bocq_next_step1        bocq_next_step2
# 29153             NaN  Wisdom Tooth Workshop
# 43222             NaN  Wisdom Tooth Workshop
# 49261             NaN  Wisdom Tooth Workshop
# 54266             NaN  Wisdom Tooth Workshop
# 54375             NaN  Wisdom Tooth Workshop

# %%
#slice based on 2 unique values
bocq4=smile_on.loc[(smile_on["bocq_next_step2"] == "Services not available within SMILE ON")]
bocq4.loc[:,['bocq_next_step1', 'bocq_next_step2']]
# Out:
# 2     bocq_next_step1                         bocq_next_step2
# 27524             NaN  Services not available within SMILE ON
# 36201             NaN  Services not available within SMILE ON
# 36999             NaN  Services not available within SMILE ON
# 39268             NaN  Services not available within SMILE ON
# 41926             NaN  Services not available within SMILE ON
# 44068             NaN  Services not available within SMILE ON
# 45063             NaN  Services not available within SMILE ON
# 48429             NaN  Services not available within SMILE ON
# 48431             NaN  Services not available within SMILE ON
# 51049             NaN  Services not available within SMILE ON
# 55655             NaN  Services not available within SMILE ON
# 57297             NaN  Services not available within SMILE ON
# 57352             NaN  Services not available within SMILE ON

# %%
smile_on['bocq_next_step'] = smile_on['bocq_next_step1'].fillna(smile_on['bocq_next_step2'])
smile_on = smile_on.drop('bocq_next_step1', axis=1)
smile_on = smile_on.drop('bocq_next_step2', axis=1)
smile_on.shape
# Out:
# (57860, 114)

# %% [markdown]
# # Demographic Information - Language merging two columns together

# %%
#cell to explore contents of various cells
lang1 = smile_on['di_language1'].unique()
lang1
# Out:
# array(['English', nan, 'Other', 'Spanish', 'Arabic'], dtype=object)

# %%
smile_on["di_language1"].value_counts()
# Out:
# English    14013
# Spanish     2127
# Other        730
# Arabic       494
# Name: di_language1, dtype: int64

# %%
#cell to explore contents of various cells
lang2 = smile_on['di_other_language'].unique()
lang2
# Out:
# array([nan, 'Farsi', 'Amharic', 'Mandarin', 'Burmese', 'Laotian',
#        'East African', 'Pakistani', 'Laos', 'Kunama', 'Swahili',
#        'English', 'Hindi', 'French', 'Kinyarwanda', 'Vietnam', 'Korean',
#        'Vietnamese', 'Bengali', 'Ethiopian', 'Nepali', 'Mayan', 'Persian',
#        'Urdu', 'Russian', 'Somali', 'Kurdish', 'Kurdish-Badini',
#        'Ahmaric', 'Chinese', 'Armenian', 'Sign Language', 'Romanian',
#        'farsi', 'Greek', 'Ukranian', 'hatian', 'Gujrati', 'Ijbo'],
#       dtype=object)

# %%
smile_on["di_other_language"].value_counts()
# Out:
# Farsi             12
# Amharic           10
# Kurdish           10
# Mandarin          10
# Russian            7
# Burmese            7
# Korean             6
# Laotian            5
# Nepali             5
# Vietnamese         5
# French             5
# Hindi              4
# Laos               4
# Somali             4
# Chinese            4
# East African       3
# Sign Language      3
# Ahmaric            3
# Mayan              3
# Kunama             3
# English            2
# Kinyarwanda        2
# Gujrati            2
# Swahili            2
# Ethiopian          2
# hatian             2
# Pakistani          1
# farsi              1
# Persian            1
# Ukranian           1
# Urdu               1
# Vietnam            1
# Romanian           1
# Kurdish-Badini     1
# Armenian           1
# Bengali            1
# Ijbo               1
# Greek              1
# Name: di_other_language, dtype: int64

# %%
compare_lang = (smile_on['di_language1'].notnull() == smile_on['di_other_language'].notnull()).all()
compare_lang
# Out:
# False

# %%
smile_on['di_language'] = smile_on['di_language1'].fillna(smile_on['di_other_language'])
smile_on = smile_on.drop('di_language', axis=1)
smile_on = smile_on.drop('di_other_language', axis=1)
smile_on.shape
# Out:
# (57860, 113)

# %%
smile_on["patient_id"].value_counts()
# Out:
# -1         63
# 3212379    54
# 2441776    43
# 2758373    42
# 2431132    37
#            ..
# 2710572     1
# 2483634     1
# 3148012     1
# 3041102     1
# 4527889     1
# Name: patient_id, Length: 10711, dtype: int64

# %%
patient_3212379 = smile_on[smile_on["patient_id"] == "3212379"]
patient_3212379
# Out:
# 2     report_num             report_version related_reports        call_start  \
# 3797    90620697  SMILE ON 60+ Registration             NaN    7/26/2021 8:08
# 3870    90475194  SMILE ON 60+ Registration             NaN   7/22/2021 16:08
# 3886    90468599  SMILE ON 60+ Registration             NaN   7/22/2021 13:54
# 3959    90664529      SMILE ON 60+ Clinical             NaN    7/22/2021 8:46
# 4258    90248254  SMILE ON 60+ Registration             NaN   7/16/2021 11:08
# 4665    90161849  SMILE ON 60+ Registration             NaN     7/9/2021 9:13
# 4923    89866591  SMILE ON 60+ Registration             NaN    7/6/2021 10:01
# 5075    89866858  SMILE ON 60+ Registration             NaN    7/1/2021 10:06
# 5084    89865303      SMILE ON 60+ Clinical             NaN     7/1/2021 9:33
# 5565    89458311  SMILE ON 60+ Registration             NaN    6/24/2021 9:40
# 6017    89176544  SMILE ON 60+ Registration             NaN   6/16/2021 12:31
# 20377   9/25/2020 11:00           3    3212379       Hohenwald  Lewis    TN
# 20497   9/23/2020 15:52           0    3212379       Hohenwald  Lewis    TN
# 21563    9/2/2020 15:04           3    3212379       Hohenwald  Lewis    TN
# 22367   8/20/2020 10:18           1    3212379       Hohenwald  Lewis    TN
# 22402   8/19/2020 16:15           1    3212379       Hohenwald  Lewis    TN
# 22406   8/19/2020 15:52           2    3212379       Hohenwald  Lewis    TN
# 23581    7/27/2020 9:32           2    3212379       Hohenwald  Lewis    TN
# 23756    7/22/2020 9:53           2    3212379       Hohenwald  Lewis    TN
# 23774   7/21/2020 14:19           2    3212379       Hohenwald  Lewis    TN
# 23775   7/21/2020 14:17           1    3212379       Hohenwald  Lewis    TN
# 23872   7/20/2020 12:50           3    3212379       Hohenwald  Lewis    TN
# 24459    7/7/2020 16:10           4    3212379       Hohenwald  Lewis    TN
# 24570    7/6/2020 11:17           3    3212379       Hohenwald  Lewis    TN
# 27928    3/16/2020 9:41           4    3212379       Hohenwald  Lewis    TN
# 28178   3/11/2020 11:42           2    3212379       Hohenwald  Lewis    TN
# 28355    3/10/2020 9:28           2    3212379       Hohenwald  Lewis    TN
# 29208   2/27/2020 14:20           2    3212379       Hohenwald  Lewis    TN
#
# 2      ...                          scrn_urgency scrn_decay  \
# 3797   ...                                   NaN        NaN
# 3870   ...                                   NaN        NaN
# 3886   ...                                   NaN        NaN
# 3959   ...                                   NaN        NaN
# 4258   ...                                   NaN        NaN
# 4665   ...                                   NaN        NaN
# 4923   ...                                   NaN        NaN
# 5075   ...                                   NaN        NaN
# 5084   ...                                   NaN        NaN
# 5565   ...                                   NaN        NaN
# 6017   ...                                   NaN        NaN
# 6376   ...                                   NaN        NaN
# 6698   ...                                   NaN        NaN
# 6875   ...                                   NaN        NaN
# 7120   ...                                   NaN        NaN
# 7290   ...                                   NaN        NaN
# 7804   ...                                   NaN        NaN
# 7824   ...                                   NaN        NaN
# 7862   ...                                   NaN        NaN
# 8073   ...                                   NaN        NaN
# 11065  ...                                   NaN        NaN
# 11599  ...                                   NaN        NaN
# 11673  ...                                   NaN        NaN
# 11757  ...                                   NaN        NaN
# 11770  ...                                   NaN        NaN
# 12288  ...                                   NaN        NaN
# 14096  ...                                   NaN        NaN
# 14226  ...                                   NaN        NaN
# 14229  ...                                   NaN        NaN
# 14416  ...                                   NaN        NaN
# 16712  ...                                   NaN        NaN
# 16763  ...                                   NaN        NaN
# 17598  ...                                   NaN        NaN
# 17658  ...                                   NaN        NaN
# 18445  ...                                   NaN        NaN
# 18627  ...                                   NaN        NaN
# 19086  ...                                   NaN        NaN
# 20377  ...                                   NaN        NaN
# 20497  ...                                   NaN        NaN
# 21563  ...                                   NaN        NaN
# 22367  ...                                   NaN        NaN
# 22402  ...                                   NaN        NaN
# 22406  ...                                   NaN        NaN
# 23581  ...                                   NaN        NaN
# 23756  ...                                   NaN        NaN
# 23774  ...  Early care-within next several weeks        Yes
# 23775  ...                                   NaN        NaN
#        'Interfaith Dental Clinic - Nashville',
#        'Northeast Tennessee Community Health Centers Inc. - Johnson City',
#        'Matthew Walker Comprehensive Health Center Inc. - Nashville',
#        'Christ Community Health Services- Hickory Hill',
#        'Keystone Dental Care Inc. - Johnson City',
#        'Friends in Need Health Center - Kingsport',
#        'Interfaith Health Clinic of Knoxville - Knoxville',
#        'Meharry Mobile Dental Clinic', 'Matthew Walker - Clarksville',
#        'Mountain Hope Good Shepherd Clinic', 'TDH - Maury Co',
#        'Reelfoot Ministries - Obion', 'Church Health Center - Memphis',
#        'Trinity Health Ministries ',
#        'Smiles Inc. - South Pittsburg - serving Marion Grundy Franklin and Hamilton Counties',
#        'Neighborhood Health - Napier/Nashville',
#        'Christ Community Health Services- Third Street',
#        'Fifty Forward - Nashville', 'TDH - Lawrence Co',
#        'Knox County CAC/Office on Aging - Knoxville',
#        'Neighborhood Health - Eastside/Nashville',
#        'Neighborhood Health - Mission/Nashville',
#        'Appalachian Miles for Smiles - Mobile'], dtype=object)

# %%
#total patients seen per clinic
smile_on["si_enroller_id"].value_counts()
# Out:
# Interfaith Dental Clinic - Nashville                                                    7995
# Interfaith Dental Clinic - Murfreesboro                                                 5100
# Church Health Center - Memphis                                                          5074
# Matthew Walker Comprehensive Health Center Inc. - Nashville                             3281
# Interfaith Health Clinic of Knoxville - Knoxville                                       2738
# Karis Dental Clinic - Cleveland                                                         2301
# Friends in Need Health Center - Kingsport                                               2089
# Healing Hands Health Center - Bristol                                                   1933
# Christ Community Health Services- Hickory Hill                                          1575
# Keystone Dental Care Inc. - Johnson City                                                1512
# Christ Community Health Services- Frayser                                               1377
# Christ Community Health Services- Broad Avenue                                          1281
# Neighborhood Health - Cleveland Park/ Nashville                                         1236
# Christ Community Health Services- Raleigh                                               1095
# Matthew Walker - Clarksville                                                             982
# TDH - Maury Co                                                                           932
# Northeast Tennessee Community Health Centers Inc. - Johnson City                         873
# Neighborhood Health - Lebanon                                                            866
# Christ Community Health Services- Third Street                                           824
# Neighborhood Health - Napier/Nashville                                                   710
# Trinity Health Ministries                                                                486
# TDH - Lawrence Co                                                                        446
# Neighborhood Health - Eastside/Nashville                                                 444
# Smiles Inc. - South Pittsburg - serving Marion Grundy Franklin and Hamilton Counties     386
# Reelfoot Ministries - Obion                                                              347
# Knox County CAC/Office on Aging - Knoxville                                              272
# Meharry Mobile Dental Clinic                                                             249
# Appalachian Miles for Smiles - Mobile                                                    206
# Mountain Hope Good Shepherd Clinic                                                       164
# Neighborhood Health - Mission/Nashville                                                  132
# Fifty Forward - Nashville                                                                103
# Name: si_enroller_id, dtype: int64

# %%
#total patients seen at all clinics
smile_on["si_enroller_id"].value_counts().sum()
# Out:
# 47009

# %%
#combining two columns that have the same information, but only one seems to be used depending on the record
#smile_on = smile_on['bocq_next_step1'].fillna(smile_on['bocq_next_step2'])

# %%
# how many clinics drafted treatment plans? (not necessarily indicator of success if treatment plan was not needed)
# how many clinics restored full functionality to patient?
# how many clinics saw a patient multiple times?
