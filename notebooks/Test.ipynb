# %%
import pandas as pd
import numpy as np
import pickle
pd.set_option('display.max_columns', None)

# %%
# %%time
smileon = pd.read_pickle("../data/smileon.pkl")
# Out:
# Wall time: 283 ms

# %%
smileon.head(2)
# Out:
#    CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0       93115324  SMILE ON 60+ Registration                   NaN
# 1       93115188  SMILE ON 60+ Registration                   NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0      9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1      9/30/2021 16:53    9/30/2021 16:53           0    4431194
#
#    PhoneWorkerNum   CityName  CountyName StateProvince    CountryName  \
# 0          123747     Smyrna  Rutherford            TN  United States
# 1          123747  Nashville    Davidson            TN  United States
#
#    PostalCode PhoneType ThirdPartyStateProvince  \
# 0     37167.0    Mobile                     NaN
# 1     37211.0       NaN                     NaN
#
#                                            Narrative Feedback  \
# 0  spoke with client again concerning transfer to...      NaN
# 1  Called client to follow up on app. LM for call...      NaN
#
# ...

# %%
smileon.sum(skipna=True)
# Out:
# CallReportNum                                                          4291676390880
# ReportVersion                      SMILE ON 60+ RegistrationSMILE ON 60+ Registra...
# CallDateAndTimeStart               9/30/2021 16:569/30/2021 16:539/30/2021 16:509...
# CallDateAndTimeEnd                 9/30/2021 16:579/30/2021 16:539/30/2021 16:519...
# CallLength                                                                    237013
#                                                          ...
# OralCare_7972                                                                    1.0
# OralCare_9110                                                                   27.0
# OralCare_9951                                                                   83.0
# Screen_# of Lower Natural Teeth                                              63020.0
# Screen_# of Upper Natural Teeth                                              52664.0
# Length: 61, dtype: object

# %%
oral_care=smileon[['OralCare_1351','OralCare_1354','OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980', 'OralCare_3220','OralCare_4341','OralCare_4342','OralCare_6930','OralCare_6980','OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972','OralCare_9110','OralCare_9951']]
oral_care.head(2)
# Out:
#        OralCare_1351  OralCare_1354  OralCare_2140  OralCare_2150  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 57855            NaN            NaN            NaN            NaN
# 57856            NaN            NaN            NaN            NaN
# 57857            NaN            NaN            NaN            NaN
# 57858            NaN            NaN            NaN            NaN
# 57859            NaN            NaN            NaN            NaN
#
#        OralCare_2160  OralCare_2161  OralCare_230  OralCare_2330  \
# 0                NaN            NaN           NaN            NaN
# ...

# %% [markdown]
# **Finding the sum of values in each column excluding NaN values

# %%
oral_care.count()
# Out:
# OralCare_1351      12
# OralCare_1354     892
# OralCare_2140      50
# OralCare_2150     104
# OralCare_2160      46
# OralCare_2161      10
# OralCare_230     1337
# OralCare_2330     944
# OralCare_2331     940
# OralCare_2332     579
# OralCare_2335     428
# OralCare_2390       8
# OralCare_2391    1226
# OralCare_2392    1341
# OralCare_2393     635
# OralCare_2394     171
# OralCare_2915       2
# OralCare_2920     134
# OralCare_2933      19
# OralCare_2940      74
# OralCare_2950     337
# OralCare_2954      15
# OralCare_2980       3
# OralCare_3220       7
# OralCare_4341    1396
# OralCare_4342     579
# OralCare_6930      12
# OralCare_6980       2
# OralCare_7111       9
# OralCare_7140    4979
# OralCare_7210     819
# OralCare_7220       5
# OralCare_7230       6
# OralCare_7240      19
# OralCare_7241       3
# OralCare_7250     486
# OralCare_7261       1
# OralCare_7286      68
# OralCare_7310     225
# OralCare_7311      30
# OralCare_7320     100
# ...

# %%
df = pd.DataFrame({"Procedure: ['OralCare_1351','OralCare_1354','OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980', 'OralCare_3220','OralCare_4341','OralCare_4342','OralCare_6930','OralCare_6980','OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972','OralCare_9110','OralCare_9951'], "counts": [892,50, 104, 46, 10, 1337, 944, 940, 579, 428, 8, 1226, 1341, 635, 171, 2, 134, 19, 74, 337, 15, 3, 7, 1396, 579, 12, 2, 9, 4979, 819, 5, 6, 19, 3, 486, 1, 68, 225, 30, 100, 80, 6, 1, 4, 12, 2, 1,26, 83]})
x_pos = np.arange(df.shape[0])
plt.bar(x_pos, df.counts, align='center', color=['green', 'blue'], alpha=0.5)
plt.xticks(x_pos, df.STATUS)
plt.ylabel('Counts')
plt.title('Procedure')
plt.show()
# Out:
#   File "<ipython-input-105-7191cb3fb585>", line 1
# ...

# %% [markdown]
# cats = np.random.choice(["Active", "Terminated"], 100, p=[0.43, 0.57])
# df = pd.DataFrame({"ID": np.arange(100), "Status":cats, "unusedData":np.random.rand(100)})
#
# df_count = df[["Status"]].apply(pd.value_counts)
# df_count.plot(kind="bar")
#
# plt.show()

# %%
oral_care.describe()
# Out:
#        OralCare_1351  OralCare_1354  OralCare_2140  OralCare_2150  \
# count      12.000000     892.000000      50.000000     104.000000
# mean        2.416667       3.242152       1.280000       1.057692
# std         2.353270       3.038418       1.050559       0.234290
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       1.000000       1.000000       1.000000
# 50%         1.000000       2.000000       1.000000       1.000000
# 75%         2.500000       4.000000       1.000000       1.000000
# max         8.000000      22.000000       8.000000       2.000000
#
#        OralCare_2160  OralCare_2161  OralCare_230  OralCare_2330  \
# count      46.000000           10.0   1337.000000     944.000000
# mean        1.043478            1.0      2.549738       1.507415
# std         0.206185            0.0      2.173077       1.027691
# min         1.000000            1.0      1.000000       1.000000
# ...

# %%
smileon.pivot(index='group2', columns='Month', values = 'count').plot(kind='bar',figsize=(15,8))
plt.xlabel('Procedure')
plt.ylabel('Number of Procedures')
plt.title('Total Number of Procedures')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-18a6251137ab> in <module>
# ...

# %% [markdown]
# group0= ['OralCare_230'] #XRay
# group1 =['OralCare_1351','OralCare_1354'] #Cavity_Sealants
#
# group2 =['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980'] #Restorative
#
# group3 = ['OralCare_3220'] #Kids Dental
# group4 = ['OralCare_4341','OralCare_4342'] #Non-Surgical
# group6 = ['OralCare_6930','OralCare_6980'] #Denture Repair
#
# group7 = ['OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972'] #Oral Surgery
#
# group9 = ['OralCare_9110','OralCare_9951']

# %% [markdown]
# oral_care = np.array(oral_care).astype('float32')

# %% [markdown]
# tp = smileon[['TPlan_Is the treatment plan completed?','TPlan_Was a treatment plan developed?']]

# %%
XRay = smileon.groupby('OralCare_230')['OralCare_230'].value_counts()
XRay
# Out:
# OralCare_230  OralCare_230
# 1.0           1.0             535
# 2.0           2.0             329
# 3.0           3.0             175
# 4.0           4.0             101
# 5.0           5.0             104
# 6.0           6.0              40
# 7.0           7.0              16
# 8.0           8.0              14
# 9.0           9.0               3
# 10.0          10.0              5
# 11.0          11.0              2
# 12.0          12.0              2
# 13.0          13.0              1
# 14.0          14.0              1
# 17.0          17.0              9
# Name: OralCare_230, dtype: int64

# %%
XRay.sum()
# Out:
# 1337

# %%
smileon.groupby(['OralCare_1351','OralCare_1354'],dropna=False)['CallerNum'].agg(['count'])
# Out:
#                              count
# OralCare_1351 OralCare_1354
# 1.0           NaN                7
# 2.0           NaN                2
# 4.0           NaN                1
# 6.0           NaN                1
# 8.0           NaN                1
# NaN           1.0              315
#               2.0              182
#               3.0              117
#               4.0               77
#               5.0               60
#               6.0               37
#               7.0               31
#               8.0               17
#               9.0               17
#               10.0               8
#               11.0               6
#               12.0               1
#               13.0               7
#               14.0               5
#               15.0               3
#               16.0               3
#               17.0               1
#               18.0               2
#               19.0               1
#               20.0               1
# ...

# %%
Cavity_Sealants=smileon.groupby(['OralCare_1351','OralCare_1354'],as_index=False, dropna=False).CallerNum.agg(['count'])
#.SALARY.mean()
Cavity_Sealants
# Out:
#                              count
# OralCare_1351 OralCare_1354
# 1.0           NaN                7
# 2.0           NaN                2
# 4.0           NaN                1
# 6.0           NaN                1
# 8.0           NaN                1
# NaN           1.0              315
#               2.0              182
#               3.0              117
#               4.0               77
#               5.0               60
#               6.0               37
#               7.0               31
#               8.0               17
#               9.0               17
#               10.0               8
#               11.0               6
#               12.0               1
#               13.0               7
#               14.0               5
#               15.0               3
#               16.0               3
#               17.0               1
#               18.0               2
#               19.0               1
#               20.0               1
# ...

# %%
group0= smileon['OralCare_230']
group1 =smileon[['OralCare_1351','OralCare_1354']]
group2 = smileon[['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980']]
group3 = smileon[['OralCare_3220']]
group4 = smileon[['OralCare_4341','OralCare_4342']]
group6 = smileon[['OralCare_6930','OralCare_6980']]
group7 = smileon[['OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972']]
group9 = smileon[['OralCare_9110','OralCare_9951']]

# %%
group0=smileon['OralCare_230']

# %%
group0.count()
# Out:
# 1337

# %%
group0.value_counts()
# Out:
# 1.0     535
# 2.0     329
# 3.0     175
# 5.0     104
# 4.0     101
# 6.0      40
# 7.0      16
# 8.0      14
# 17.0      9
# 10.0      5
# 9.0       3
# 11.0      2
# 12.0      2
# 14.0      1
# 13.0      1
# Name: OralCare_230, dtype: int64

# %%
group1.count()
# Out:
# OralCare_1351     12
# OralCare_1354    892
# dtype: int64

# %%
group1.mean(skipna=True)
# Out:
# OralCare_1351    2.416667
# OralCare_1354    3.242152
# dtype: float64

# %%
group2.count()
# Out:
# OralCare_2140      50
# OralCare_2150     104
# OralCare_2160      46
# OralCare_2161      10
# OralCare_230     1337
# OralCare_2330     944
# OralCare_2331     940
# OralCare_2332     579
# OralCare_2335     428
# OralCare_2390       8
# OralCare_2391    1226
# OralCare_2392    1341
# OralCare_2393     635
# OralCare_2394     171
# OralCare_2915       2
# OralCare_2920     134
# OralCare_2933      19
# OralCare_2940      74
# OralCare_2950     337
# OralCare_2954      15
# OralCare_2980       3
# dtype: int64

# %%
group3.count()
# Out:
# OralCare_3220    7
# dtype: int64

# %%
group4.count()
# Out:
# OralCare_4341    1396
# OralCare_4342     579
# dtype: int64

# %%
group6.count()
# Out:
# OralCare_6930    12
# OralCare_6980     2
# dtype: int64

# %%
group7.count()
# Out:
# OralCare_7111       9
# OralCare_7140    4979
# OralCare_7210     819
# OralCare_7220       5
# OralCare_7230       6
# OralCare_7240      19
# OralCare_7241       3
# OralCare_7250     486
# OralCare_7261       1
# OralCare_7286      68
# OralCare_7310     225
# OralCare_7311      30
# OralCare_7320     100
# OralCare_7321      80
# OralCare_7410      16
# OralCare_7411       1
# OralCare_7471       4
# OralCare_7510      12
# OralCare_7971       2
# OralCare_7972       1
# dtype: int64

# %%
group9.count()
# Out:
# OralCare_9110    26
# OralCare_9951    83
# dtype: int64

# %%
filt_tpd = smileon['TPlan_Was a treatment plan developed?']=='Yes'
smileon.loc[filt_tpd]['TPlan_Is the treatment plan completed?'].str.contains('Yes').sum()

#'TPlan_Is the treatment plan completed?','TPlan_Was a treatment plan developed?'
# Out:
# 6649

# %%
group1['CallerNum'].count().reset_index() #CallerNum represents a Unique ID number for each patient
# Out:
#     OralCare_1351  OralCare_1354  CallerNum
# 0             1.0            NaN          7
# 1             2.0            NaN          2
# 2             4.0            NaN          1
# 3             6.0            NaN          1
# 4             8.0            NaN          1
# 5             NaN            1.0        315
# 6             NaN            2.0        182
# 7             NaN            3.0        117
# 8             NaN            4.0         77
# 9             NaN            5.0         60
# 10            NaN            6.0         37
# 11            NaN            7.0         31
# 12            NaN            8.0         17
# 13            NaN            9.0         17
# 14            NaN           10.0          8
# 15            NaN           11.0          6
# 16            NaN           12.0          1
# 17            NaN           13.0          7
# 18            NaN           14.0          5
# 19            NaN           15.0          3
# ...

# %% [markdown]
# 0 = ['OralCare_0230']
# 1 = ['OralCare_1351','OralCare_1354']
# 2 = ['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980']
# 3 = c
# 4 = ['OralCare_4341','OralCare_4342']
# 6 = ['OralCare_6930','OralCare_6980']
# 7 = c
# 9 = ['OralCare_9110','OralCare_9951']
#
# if 1:
#     print ('Cavity Sealants')
#     if 2:
#         print ('Restorative')
#         if 3:
#             print ('Kids Dental')
#             if 4:
#                 print ('Non-Surgical')
#                     if 6:
#                         print ('Denture Repair')
#                         if 7:
#                             print ('Oral Surgery')
#                             if 9:
#                                 print
#                             else:
#                                   print ('xray')

# %% [markdown]
# **Using CallerNum to count the patients with OralCare 1300/Cavity Sealant treatments

# %% [markdown]
# ** Grouping results base on question 'Was a treatment plan developed' and honing in on 'Yes'responses

# %%
grouped_tpdy['CallerNum'].value_counts()
# Out:
# 2849688    31
# 2860770    26
# 2891340    25
# 2867207    23
# 2937961    22
#            ..
# 3025506     1
# 4470934     1
# 2449047     1
# 4266612     1
# 4158973     1
# Name: CallerNum, Length: 6346, dtype: int64

# %% [markdown]
# group0= smileon['OralCare_230']
# group1 =smileon.groupby(['OralCare_1351','OralCare_1354'],dropna=False)
# group2 = smileon.groupby(['OralCare_2140','OralCare_2150','OralCare_2160','OralCare_2161','OralCare_230','OralCare_2330','OralCare_2331','OralCare_2332','OralCare_2335','OralCare_2390','OralCare_2391','OralCare_2392','OralCare_2393','OralCare_2394','OralCare_2915','OralCare_2920','OralCare_2933','OralCare_2940','OralCare_2950','OralCare_2954','OralCare_2980'])
# group3 = smileon['OralCare_3220']
# group4 = smileon.groupby(['OralCare_4341','OralCare_4342'])
# group6 = smileon.groupby(['OralCare_6930','OralCare_6980'])
# group7 = smileon.groupby(['OralCare_7111','OralCare_7140','OralCare_7210','OralCare_7220','OralCare_7230','OralCare_7240','OralCare_7241','OralCare_7250','OralCare_7261','OralCare_7286','OralCare_7310','OralCare_7311','OralCare_7320','OralCare_7321','OralCare_7410','OralCare_7411','OralCare_7471','OralCare_7510','OralCare_7971','OralCare_7972'])
# group9 = smileon.groupby(['OralCare_9110','OralCare_9951'])
